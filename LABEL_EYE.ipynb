# %% [markdown]
# Fix rec_time for data that is not all together

# %%
import csv
import datetime

def add_time_to_csv(input_file, output_file, add_minutes, add_seconds):
    updated_rows = []

    with open(input_file, 'r') as file:
        reader = csv.reader(file)
        headers = next(reader)  # Extract headers from the first row
        updated_rows.append(headers)

        for row in reader:
            record = row[0]  # Assuming rec_time is the first column
            time_parts = record.split(":")
            minutes = int(time_parts[0])
            seconds, microseconds = map(int, time_parts[1].split("."))

            time_delta = datetime.timedelta(minutes=add_minutes, seconds=add_seconds)
            updated_time = datetime.datetime(1, 1, 1, 0, minutes, seconds, microseconds) + time_delta

            # Format microseconds with a single digit
            updated_microseconds_str = str(updated_time.microsecond)[:1]

            # Update the rec_time value in the row
            row[0] = f"{updated_time.strftime('%M:%S')}.{updated_microseconds_str}"
            updated_rows.append(row)

    with open(output_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(updated_rows)

input_file = '/content/drive/MyDrive/Data/Eye_Tracker/Fix.csv'
output_file = '/content/drive/MyDrive/Data/Eye_Tracker/Fixed.csv'
add_minutes = 40
add_seconds = 13

add_time_to_csv(input_file, output_file, add_minutes, add_seconds)

# %% [markdown]
# Add an open or close tag (processed data)

# %%
import pandas as pd
from google.colab import files

# Read in the CSV file
input_file_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M.csv'
output_file_name = 'Eye_Label.csv'

df = pd.read_csv(input_file_path)

# create a new column named eye_state
df['eye_state'] = 'open'

# loop through each row
for index, row in df.iterrows():

    # check if the current row has NaN for both left and right pupil area
    if pd.isna(row['Dikablis Glasses 3_Eye Data_Processed Data_Left Eye_Pupil Area']) and pd.isna(row['Dikablis Glasses 3_Eye Data_Processed Data_Right Eye_Pupil Area']):

        # check if the previous row had 0 for either left or right pupil area
        if index > 0 and (df.loc[index-1, 'Dikablis Glasses 3_Eye Data_Processed Data_Left Eye_Pupil Area'] == 0 or df.loc[index-1, 'Dikablis Glasses 3_Eye Data_Processed Data_Right Eye_Pupil Area'] == 0):

            # set the eye state to closed
            df.loc[index, 'eye_state'] = 'closed'

    # check if either left or right pupil area is 0 in the current row
    elif row['Dikablis Glasses 3_Eye Data_Processed Data_Left Eye_Pupil Area'] == 0 or row['Dikablis Glasses 3_Eye Data_Processed Data_Right Eye_Pupil Area'] == 0:

        # set the eye state to closed
        df.loc[index, 'eye_state'] = 'closed'

# save the updated data to a new CSV file
output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
df.to_csv(output_file_path, encoding='utf-8-sig')
print(f"Updated file saved at: {output_file_path}")
# Out:
#   rec_time            UTC  \
# 0  00:00.0  1684352435577
# 1  00:00.1  1684352435607
# 2  00:00.1  1684352435610
# 3  00:00.1  1684352435613
# 4  00:00.1  1684352435623
#
#    Dikablis Glasses 3_Eye Data_Processed Data_Left Eye_Pupil Area  \
# 0                                                NaN
# 1                                            884.447
# 2                                                NaN
# 3                                                NaN
# 4                                            930.989
#
#    Dikablis Glasses 3_Eye Data_Processed Data_Right Eye_Pupil Area eye_state
# 0                                                NaN                    open
# 1                                                NaN                    open
# 2                                                NaN                    open
# 3                                            809.475                    open
# 4                                                NaN                    open

# %% [markdown]
# Add an open or close tag (original data)

# %%
import pandas as pd
from google.colab import files

# Read in the CSV file
input_file_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M.csv'
output_file_name = 'Eye_Label.csv'

df = pd.read_csv(input_file_path)

# create a new column named eye_state
df['eye_state'] = 'open'

# loop through each row
for index, row in df.iterrows():

    # check if the current row has NaN for both left and right pupil area
    if pd.isna(row['Dikablis Glasses 3_Eye Data_Original_Left Eye_Pupil Area']) and pd.isna(row['Dikablis Glasses 3_Eye Data_Original_Right Eye_Pupil Area']):

        # check if the previous row had 0 for either left or right pupil area
        if index > 0 and (df.loc[index-1, 'Dikablis Glasses 3_Eye Data_Original_Left Eye_Pupil Area'] == 0 or df.loc[index-1, 'Dikablis Glasses 3_Eye Data_Original_Right Eye_Pupil Area'] == 0):

            # set the eye state to closed
            df.loc[index, 'eye_state'] = 'closed'

    # check if either left or right pupil area is 0 in the current row
    elif row['Dikablis Glasses 3_Eye Data_Original_Left Eye_Pupil Area'] == 0 or row['Dikablis Glasses 3_Eye Data_Original_Right Eye_Pupil Area'] == 0:

        # set the eye state to closed
        df.loc[index, 'eye_state'] = 'closed'

# save the updated data to a new CSV file
output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
df.to_csv(output_file_path, encoding='utf-8-sig')

print(f"Updated file saved at: {output_file_path}")
# Out:
#   rec_time           UTC  \
# 0  00:00.0  1.681930e+12
# 1  00:00.0  1.681930e+12
# 2  00:00.0  1.681930e+12
# 3  00:00.0  1.681930e+12
# 4  00:00.1  1.681930e+12
#
#    Dikablis Glasses 3_Eye Data_Original_Left Eye_Pupil Area  \
# 0                                                NaN
# 1                                            638.476
# 2                                                NaN
# 3                                                NaN
# 4                                            637.022
#
#    Dikablis Glasses 3_Eye Data_Original_Right Eye_Pupil Area eye_state
# 0                                                NaN              open
# 1                                                NaN              open
# 2                                            613.919              open
# 3                                                NaN              open
# 4                                                NaN              open

# %% [markdown]
# Calculate PERCLOS

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
# drive.mount('/content/drive')

# File paths
input_file_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Labelled_Data.csv'
output_file_name = 'PERCLOS.csv'

# Read the CSV file
df = pd.read_csv(input_file_path)

start_time = df['UTC'].iloc[0]
count=0
# calculate perclos for every 30 seconds
for i in range(len(df)):
    # calculate time difference in seconds
    time_diff = (df['UTC'][i] - start_time)
    if time_diff >= 30000:
        # calculate perclos for the last 30 seconds
        last_30_sec = df[(df['UTC'] >= df['UTC'][i] - 30000) & (df['UTC'] <= df['UTC'][i])]
        #print((last_30_sec['eye_state'] == 'closed').sum())
        # last_30_sec = df[(df['UTC'] >= df['UTC'][i] - 30000) & (df['UTC'] <= df['UTC'][i])]
        closed_frames = len(last_30_sec[last_30_sec['eye_state'] == 'closed'])
        perclos = (closed_frames / len(last_30_sec))* 100
        # perclos = ((last_30_sec['eye_state'] == 'closed').sum() / len(last_30_sec) )* 100

        # set the perclos value for each row in the last 30 seconds
        df.loc[(df['UTC'] >= df['UTC'][i] - 30000) & (df['UTC'] <= df['UTC'][i]), 'perclos'] = perclos
        # update start time
        start_time = df['UTC'][i]
        if(perclos>=10):
          print('DROWSYYYYY')
          print(perclos)
          print(count)
        count+=1
# calculate the final period

last_row_index = len(df) - 1
last_30_sec = df[(df['UTC'] >= start_time+1) & (df.index <= last_row_index)]
perclos = (last_30_sec['eye_state'] == 'closed').sum() / len(last_30_sec) * 100

# set the perclos value for each row in the last period
df.loc[(df['UTC'] >= start_time) & (df.index <= last_row_index), 'perclos'] = perclos
if(perclos>10):
  print('DROWSYYYYY')
  print(perclos)

# Save the updated data to a new CSV file in the same folder
output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
df.to_csv(output_file_path, encoding='utf-8-sig')

print(f"Updated file saved at: {output_file_path}")
# Out:
# DROWSYYYYY
# 22.689075630252102
# 59
# Updated file saved at: /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/PERCLOS.csv

# %% [markdown]
# Calculate Blink Percentage

# %%
import pandas as pd
from google.colab import drive

# File paths
input_file_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/PERCLOS.csv'
output_file_name = 'PERCLOS_BP.csv'

# Read the CSV file
df = pd.read_csv(input_file_path)

start_time = df['UTC'].iloc[0]
total_closed_time = 0
observation_time = 60

# calculate closed time for every blink
for i in range(1, len(df)):
    # check if current and previous eye state are different and the current state is closed
    if df['eye_state'][i] != df['eye_state'][i-1] and df['eye_state'][i] == 'closed':
        closed_start_time = df['UTC'][i]
        closed_end_time = closed_start_time
    # check if current and previous eye state are different and the previous state is closed
    elif df['eye_state'][i] != df['eye_state'][i-1] and df['eye_state'][i-1] == 'closed':
        closed_end_time = df['UTC'][i-1]
        total_closed_time += (closed_end_time - closed_start_time)/100
    # calculate blink percentage
    time_diff = (df['UTC'][i] - start_time)
    if time_diff >= observation_time*1000:
        blink_percentage = (total_closed_time / observation_time) * 100
        start_time = df['UTC'][i]
        total_closed_time = 0
        # Save blink percentage
        df.loc[(df['UTC'] >= df['UTC'][i] - observation_time*1000) & (df['UTC'] <= df['UTC'][i]), 'blink_percentage'] = blink_percentage
        if blink_percentage>30:
          print('DROWSYY')
          print(blink_percentage)

#print(total_closed_time)

# calculate the final period
last_row_index = len(df) - 1
last_period_start_time = start_time
last_period_df = df[df['UTC'] >= last_period_start_time]
total_closed_time_last_period = 0

blink_percentage_last_period = total_closed_time / (df['UTC'][last_row_index] - last_period_start_time) * 100

# set the perclos value for each row in the last period
df.loc[(df['UTC'] >= last_period_start_time) & (df['UTC'] <= df['UTC'][last_row_index]), 'blink_percentage'] = blink_percentage_last_period

print(blink_percentage_last_period)

# check for missing values in the blink_percentage column
missing_values = df['blink_percentage'].isna()

# fill missing values with previous non-missing value
df['blink_percentage'].fillna(method='ffill', inplace=True)

# Save the calculated blink percentage to a new CSV file
output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
df.to_csv(output_file_path, index=False, encoding='utf-8-sig')

print(f"Blink percentage saved at: {output_file_path}")
# Out:
# DROWSYY
# 37.85000000000001
# DROWSYY
# 107.25
# DROWSYY
# 39.11666666666667
# 0.021472889128675475
# Blink percentage saved at: /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/PERCLOS_BP.csv

# %% [markdown]
# Calculate Blink Rate

# %%
import pandas as pd
from google.colab import drive

# File paths
input_file_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/PERCLOS_BP.csv'
output_file_name = 'PERCLOS_BP_BF.csv'

# Read the CSV file
df = pd.read_csv(input_file_path)

start_time = df['UTC'].iloc[0]
total_closed_time = 0
observation_time = 60
number_blinks=0


# calculate closed time for every blink
for i in range(1, len(df)):
    # check if current and previous eye state are different and the current state is closed
    if df['eye_state'][i] != df['eye_state'][i-1] and df['eye_state'][i] == 'closed':
        closed_start_time = df['UTC'][i]
        closed_end_time = closed_start_time
    # check if current and previous eye state are different and the previous state is closed
    elif df['eye_state'][i] != df['eye_state'][i-1] and df['eye_state'][i-1] == 'closed':
        closed_end_time = df['UTC'][i-1]
        total_closed_time = (closed_end_time - closed_start_time)/100
        if total_closed_time>.1:
          number_blinks+=1
    # calculate blink frequency
    time_diff = (df['UTC'][i] - start_time)
    if time_diff >= observation_time*1000:
        blink_frequency = (number_blinks / 60) * 100
        start_time = df['UTC'][i]
        number_blinks = 0
        # Save blink frequency
        df.loc[(df['UTC'] >= df['UTC'][i] - observation_time*1000) & (df['UTC'] <= df['UTC'][i]), 'blink_frequency'] = blink_frequency
        if blink_frequency>=20:
          print('DROWSYYY')
          print(blink_frequency)

print(total_closed_time)

# calculate the final period
last_row_index = len(df) - 1
last_period_start_time = start_time
last_period_df = df[df['UTC'] >= last_period_start_time]
total_closed_time_last_period = 0

blink_frequency_last_period = number_blinks / ((df['UTC'][last_row_index] - last_period_start_time)/100) * 100

# set the perclos value for each row in the last period
df.loc[(df['UTC'] >= last_period_start_time) & (df['UTC'] <= df['UTC'][last_row_index]), 'blink_frequency'] = blink_frequency_last_period

print(blink_frequency_last_period)

# check for missing values in the blink_frequency column
missing_values = df['blink_frequency'].isna()

# fill missing values with previous non-missing value
df['blink_frequency'].fillna(method='ffill', inplace=True)

# Save the calculated blink percentage to a new CSV file
output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
df.to_csv(output_file_path, index=False, encoding='utf-8-sig')

print(f"Blink percentage saved at: {output_file_path}")
# Out:
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 25.0
# DROWSYYY
# 41.66666666666667
# DROWSYYY
# 26.666666666666668
# DROWSYYY
# 25.0
# DROWSYYY
# 20.0
# DROWSYYY
# 30.0
# DROWSYYY
# 20.0
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 30.0
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 35.0
# DROWSYYY
# 28.333333333333332
# DROWSYYY
# 41.66666666666667
# DROWSYYY
# 30.0
# DROWSYYY
# 20.0
# DROWSYYY
# 35.0
# DROWSYYY
# 41.66666666666667
# DROWSYYY
# 55.00000000000001
# DROWSYYY
# 75.0
# DROWSYYY
# 35.0
# DROWSYYY
# 58.333333333333336
# DROWSYYY
# 65.0
# DROWSYYY
# 48.333333333333336
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 53.333333333333336
# DROWSYYY
# 103.33333333333334
# DROWSYYY
# 280.0
# DROWSYYY
# 53.333333333333336
# DROWSYYY
# 40.0
# DROWSYYY
# 20.0
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 81.66666666666667
# DROWSYYY
# 110.00000000000001
# DROWSYYY
# 85.0
# DROWSYYY
# 65.0
# DROWSYYY
# 38.333333333333336
# DROWSYYY
# 106.66666666666667
# DROWSYYY
# 68.33333333333333
# DROWSYYY
# 41.66666666666667
# DROWSYYY
# 63.33333333333333
# DROWSYYY
# 90.0
# DROWSYYY
# 66.66666666666666
# 0.27
# 7.013757755597519
# Blink percentage saved at: /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/PERCLOS_BP_BF.csv

# %% [markdown]
# Labeling drowsiness levels

# %%
import pandas as pd
from google.colab import drive

for x in range(12,13):
  x=str(x)
  # File paths
  input_file_path = '/content/drive/MyDrive/Data/Jose_Data_Videos_CSV/Subject_'+x+'_M/PERCLOS_BP_BF.csv'
  output_file_name = ''+x+'_M_Labels.csv'

  #define the data
  data = pd.read_csv(input_file_path)

  # Define the thresholds for each variable
  perclos_threshold = 8
  blink_percentage_threshold = 30
  blink_frequency_threshold = 20

  # Initialize an empty list to store the labels
  labels = []

  # Iterate over the rows of the data
  for index, row in data.iterrows():
      perclos = row['perclos']
      blink_percentage = row['blink_percentage']
      blink_frequency = row['blink_frequency']

      # Count the number of thresholds met
      thresholds_met = 0

      if perclos > perclos_threshold:
          thresholds_met += 1
      if blink_percentage >= blink_percentage_threshold:
          thresholds_met += 1
      if blink_frequency >= blink_frequency_threshold:
          thresholds_met += 1

      # Assign labels based on the number of thresholds met
      if thresholds_met == 0 or thresholds_met == 1:
          labels.append(0)  # Non-drowsy
      elif thresholds_met == 2:
          labels.append(1)  # Drowsy
      else:
          labels.append(2)  # Definitely drowsy or sleepy

  # Add the labels to the data
  data['Label'] = labels

  # Save the labels to a new CSV file
  output_file_path = '/'.join(input_file_path.split('/')[:-1]) + '/' + output_file_name
  data.to_csv(output_file_path, index=False, encoding='utf-8-sig')

  print(f"Labels saved at: {output_file_path}")
# Out:
# Labels saved at: /content/drive/MyDrive/Data/Jose_Data_Videos_CSV/Subject_12_M/12_M_Labels.csv

# %% [markdown]
# Count number of rows per second (FPS)

# %%
import csv

def count_rows_per_second(labels_file):
    rows_per_second = {}

    with open(labels_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            rec_time = row['rec_time']
            time_parts = rec_time.split(':')
            minute = int(time_parts[0])
            second_micro = time_parts[1].split('.')
            second = int(second_micro[0])
            microsecond = int(second_micro[1])

            total_microseconds = (minute * 60 + second) * 1000000 + microsecond
            second = total_microseconds // 1000000

            if second in rows_per_second:
                rows_per_second[second] += 1
            else:
                rows_per_second[second] = 1

    return rows_per_second

# Example usage
labels_file = '/content/drive/MyDrive/Data/Eye_Tracker/12_M_LabelsU.csv'
result = count_rows_per_second(labels_file)
max =0
# Print the counts for each second
for second, count in result.items():
    print(f"Second {second}: {count} rows")
# Out:
# Second 0: 60 rows
# Second 1: 60 rows
# Second 2: 60 rows
# Second 3: 60 rows
# Second 4: 60 rows
# Second 5: 60 rows
# Second 6: 60 rows
# Second 7: 60 rows
# Second 8: 60 rows
# Second 9: 60 rows
# Second 10: 60 rows
# Second 11: 60 rows
# Second 12: 60 rows
# Second 13: 60 rows
# Second 14: 60 rows
# Second 15: 60 rows
# Second 16: 60 rows
# Second 17: 60 rows
# Second 18: 60 rows
# Second 19: 60 rows
# Second 20: 60 rows
# Second 21: 60 rows
# Second 22: 60 rows
# Second 23: 60 rows
# Second 24: 60 rows
# Second 25: 60 rows
# Second 26: 60 rows
# Second 27: 60 rows
# Second 28: 60 rows
# Second 29: 60 rows
# Second 30: 60 rows
# Second 31: 60 rows
# Second 32: 60 rows
# Second 33: 60 rows
# Second 34: 60 rows
# Second 35: 60 rows
# Second 36: 60 rows
# Second 37: 60 rows
# Second 38: 60 rows
# Second 39: 60 rows
# Second 40: 60 rows
# Second 41: 60 rows
# Second 42: 60 rows
# Second 43: 60 rows
# Second 44: 60 rows
# Second 45: 60 rows
# Second 46: 60 rows
# Second 47: 60 rows
# Second 48: 60 rows
# Second 49: 60 rows
# Second 50: 60 rows
# Second 51: 60 rows
# Second 52: 60 rows
# Second 53: 60 rows
# Second 54: 60 rows
# Second 55: 60 rows
# Second 56: 60 rows
# Second 57: 60 rows
# Second 58: 60 rows
# Second 59: 60 rows
# Second 60: 60 rows
# Second 61: 60 rows
# Second 62: 60 rows
# Second 63: 60 rows
# Second 64: 60 rows
# Second 65: 60 rows
# Second 66: 60 rows
# Second 67: 60 rows
# Second 68: 60 rows
# Second 69: 60 rows
# Second 70: 60 rows
# Second 71: 60 rows
# Second 72: 60 rows
# Second 73: 60 rows
# Second 74: 60 rows
# Second 75: 60 rows
# Second 76: 60 rows
# Second 77: 60 rows
# Second 78: 60 rows
# Second 79: 60 rows
# Second 80: 60 rows
# Second 81: 60 rows
# Second 82: 60 rows
# Second 83: 60 rows
# Second 84: 60 rows
# Second 85: 60 rows
# Second 86: 60 rows
# Second 87: 60 rows
# Second 88: 60 rows
# Second 89: 60 rows
# Second 90: 60 rows
# Second 91: 60 rows
# Second 92: 60 rows
# Second 93: 60 rows
# Second 94: 60 rows
# Second 95: 60 rows
# Second 96: 60 rows
# Second 97: 60 rows
# Second 98: 60 rows
# Second 99: 60 rows
# Second 100: 60 rows
# Second 101: 60 rows
# Second 102: 60 rows
# Second 103: 60 rows
# Second 104: 60 rows
# Second 105: 60 rows
# Second 106: 60 rows
# Second 107: 60 rows
# Second 108: 60 rows
# Second 109: 60 rows
# Second 110: 60 rows
# Second 111: 60 rows
# Second 112: 60 rows
# Second 113: 60 rows
# Second 114: 60 rows
# Second 115: 60 rows
# Second 116: 60 rows
# Second 117: 60 rows
# Second 118: 60 rows
# Second 119: 60 rows
# Second 120: 60 rows
# Second 121: 60 rows
# Second 122: 60 rows
# Second 123: 60 rows
# Second 124: 60 rows
# Second 125: 60 rows
# Second 126: 60 rows
# Second 127: 60 rows
# Second 128: 60 rows
# Second 129: 60 rows
# Second 130: 60 rows
# Second 131: 60 rows
# Second 132: 60 rows
# Second 133: 60 rows
# Second 134: 60 rows
# Second 135: 60 rows
# Second 136: 60 rows
# Second 137: 60 rows
# Second 138: 60 rows
# Second 139: 60 rows
# Second 140: 60 rows
# Second 141: 60 rows
# Second 142: 60 rows
# Second 143: 60 rows
# Second 144: 60 rows
# Second 145: 60 rows
# Second 146: 60 rows
# Second 147: 60 rows
# Second 148: 60 rows
# Second 149: 60 rows
# Second 150: 60 rows
# Second 151: 60 rows
# Second 152: 60 rows
# Second 153: 60 rows
# Second 154: 60 rows
# Second 155: 60 rows
# Second 156: 60 rows
# Second 157: 60 rows
# Second 158: 60 rows
# Second 159: 60 rows
# Second 160: 60 rows
# Second 161: 60 rows
# Second 162: 60 rows
# Second 163: 60 rows
# Second 164: 60 rows
# Second 165: 60 rows
# Second 166: 60 rows
# Second 167: 60 rows
# Second 168: 60 rows
# Second 169: 60 rows
# Second 170: 60 rows
# Second 171: 60 rows
# Second 172: 60 rows
# Second 173: 60 rows
# Second 174: 60 rows
# Second 175: 60 rows
# Second 176: 60 rows
# Second 177: 60 rows
# Second 178: 60 rows
# Second 179: 60 rows
# Second 180: 60 rows
# Second 181: 60 rows
# Second 182: 60 rows
# Second 183: 60 rows
# Second 184: 60 rows
# Second 185: 60 rows
# Second 186: 60 rows
# Second 187: 60 rows
# Second 188: 60 rows
# Second 189: 60 rows
# Second 190: 60 rows
# Second 191: 60 rows
# Second 192: 60 rows
# Second 193: 60 rows
# Second 194: 60 rows
# Second 195: 60 rows
# Second 196: 60 rows
# Second 197: 60 rows
# Second 198: 60 rows
# Second 199: 60 rows
# Second 200: 60 rows
# Second 201: 60 rows
# Second 202: 60 rows
# Second 203: 60 rows
# Second 204: 60 rows
# Second 205: 60 rows
# Second 206: 60 rows
# Second 207: 60 rows
# Second 208: 60 rows
# Second 209: 60 rows
# Second 210: 60 rows
# Second 211: 60 rows
# Second 212: 60 rows
# Second 213: 60 rows
# Second 214: 60 rows
# Second 215: 60 rows
# Second 216: 60 rows
# Second 217: 60 rows
# Second 218: 60 rows
# Second 219: 60 rows
# Second 220: 60 rows
# Second 221: 60 rows
# Second 222: 60 rows
# Second 223: 60 rows
# Second 224: 60 rows
# Second 225: 60 rows
# Second 226: 60 rows
# Second 227: 60 rows
# Second 228: 60 rows
# Second 229: 60 rows
# Second 230: 60 rows
# Second 231: 60 rows
# Second 232: 60 rows
# Second 233: 60 rows
# Second 234: 60 rows
# Second 235: 60 rows
# Second 236: 60 rows
# Second 237: 60 rows
# Second 238: 60 rows
# Second 239: 60 rows
# Second 240: 60 rows
# Second 241: 60 rows
# Second 242: 60 rows
# Second 243: 60 rows
# Second 244: 60 rows
# Second 245: 60 rows
# Second 246: 60 rows
# Second 247: 60 rows
# Second 248: 60 rows
# Second 249: 60 rows
# Second 250: 60 rows
# Second 251: 60 rows
# Second 252: 60 rows
# Second 253: 60 rows
# Second 254: 60 rows
# Second 255: 60 rows
# Second 256: 60 rows
# Second 257: 60 rows
# Second 258: 60 rows
# Second 259: 60 rows
# Second 260: 60 rows
# Second 261: 60 rows
# Second 262: 60 rows
# Second 263: 60 rows
# Second 264: 60 rows
# Second 265: 60 rows
# Second 266: 60 rows
# Second 267: 60 rows
# Second 268: 60 rows
# Second 269: 60 rows
# Second 270: 60 rows
# Second 271: 60 rows
# Second 272: 60 rows
# Second 273: 60 rows
# Second 274: 60 rows
# Second 275: 60 rows
# Second 276: 60 rows
# Second 277: 60 rows
# Second 278: 60 rows
# Second 279: 60 rows
# Second 280: 60 rows
# Second 281: 60 rows
# Second 282: 60 rows
# Second 283: 60 rows
# Second 284: 60 rows
# Second 285: 60 rows
# Second 286: 60 rows
# Second 287: 60 rows
# Second 288: 60 rows
# Second 289: 60 rows
# Second 290: 60 rows
# Second 291: 60 rows
# Second 292: 60 rows
# Second 293: 60 rows
# Second 294: 60 rows
# Second 295: 60 rows
# Second 296: 60 rows
# Second 297: 60 rows
# Second 298: 60 rows
# Second 299: 60 rows
# Second 300: 60 rows
# Second 301: 60 rows
# Second 302: 60 rows
# Second 303: 60 rows
# Second 304: 60 rows
# Second 305: 60 rows
# Second 306: 60 rows
# Second 307: 60 rows
# Second 308: 60 rows
# Second 309: 60 rows
# Second 310: 60 rows
# Second 311: 60 rows
# Second 312: 60 rows
# Second 313: 60 rows
# Second 314: 60 rows
# Second 315: 60 rows
# Second 316: 60 rows
# Second 317: 60 rows
# Second 318: 60 rows
# Second 319: 60 rows
# Second 320: 60 rows
# Second 321: 60 rows
# Second 322: 60 rows
# Second 323: 60 rows
# Second 324: 60 rows
# Second 325: 60 rows
# Second 326: 60 rows
# Second 327: 60 rows
# Second 328: 60 rows
# Second 329: 60 rows
# Second 330: 60 rows
# Second 331: 60 rows
# Second 332: 60 rows
# Second 333: 60 rows
# Second 334: 60 rows
# Second 335: 60 rows
# Second 336: 60 rows
# Second 337: 60 rows
# Second 338: 60 rows
# Second 339: 60 rows
# Second 340: 60 rows
# Second 341: 60 rows
# Second 342: 60 rows
# Second 343: 60 rows
# Second 344: 60 rows
# Second 345: 60 rows
# Second 346: 60 rows
# Second 347: 60 rows
# Second 348: 60 rows
# Second 349: 60 rows
# Second 350: 60 rows
# Second 351: 60 rows
# Second 352: 60 rows
# Second 353: 60 rows
# Second 354: 60 rows
# Second 355: 60 rows
# Second 356: 60 rows
# Second 357: 60 rows
# Second 358: 60 rows
# Second 359: 60 rows
# Second 360: 60 rows
# Second 361: 60 rows
# Second 362: 60 rows
# Second 363: 60 rows
# Second 364: 60 rows
# Second 365: 60 rows
# Second 366: 60 rows
# Second 367: 60 rows
# Second 368: 60 rows
# Second 369: 60 rows
# Second 370: 60 rows
# Second 371: 60 rows
# Second 372: 60 rows
# Second 373: 60 rows
# Second 374: 60 rows
# Second 375: 60 rows
# Second 376: 60 rows
# Second 377: 60 rows
# Second 378: 60 rows
# Second 379: 60 rows
# Second 380: 60 rows
# Second 381: 60 rows
# Second 382: 60 rows
# Second 383: 60 rows
# Second 384: 60 rows
# Second 385: 60 rows
# Second 386: 60 rows
# Second 387: 60 rows
# Second 388: 60 rows
# Second 389: 60 rows
# Second 390: 60 rows
# Second 391: 60 rows
# Second 392: 60 rows
# Second 393: 60 rows
# Second 394: 60 rows
# Second 395: 60 rows
# Second 396: 60 rows
# Second 397: 60 rows
# Second 398: 60 rows
# Second 399: 60 rows
# Second 400: 60 rows
# Second 401: 60 rows
# Second 402: 60 rows
# Second 403: 60 rows
# Second 404: 60 rows
# Second 405: 60 rows
# Second 406: 60 rows
# Second 407: 60 rows
# Second 408: 60 rows
# Second 409: 60 rows
# Second 410: 60 rows
# Second 411: 60 rows
# Second 412: 60 rows
# Second 413: 60 rows
# Second 414: 60 rows
# Second 415: 60 rows
# Second 416: 60 rows
# Second 417: 60 rows
# Second 418: 60 rows
# Second 419: 60 rows
# Second 420: 60 rows
# Second 421: 60 rows
# Second 422: 60 rows
# Second 423: 60 rows
# Second 424: 60 rows
# Second 425: 60 rows
# Second 426: 60 rows
# Second 427: 60 rows
# Second 428: 60 rows
# Second 429: 60 rows
# Second 430: 60 rows
# Second 431: 60 rows
# Second 432: 60 rows
# Second 433: 60 rows
# Second 434: 60 rows
# Second 435: 60 rows
# Second 436: 60 rows
# Second 437: 60 rows
# Second 438: 60 rows
# Second 439: 60 rows
# Second 440: 60 rows
# Second 441: 60 rows
# Second 442: 60 rows
# Second 443: 60 rows
# Second 444: 60 rows
# Second 445: 60 rows
# Second 446: 60 rows
# Second 447: 60 rows
# Second 448: 60 rows
# Second 449: 60 rows
# Second 450: 60 rows
# Second 451: 60 rows
# Second 452: 60 rows
# Second 453: 60 rows
# Second 454: 60 rows
# Second 455: 60 rows
# Second 456: 60 rows
# Second 457: 60 rows
# Second 458: 60 rows
# Second 459: 60 rows
# Second 460: 60 rows
# Second 461: 60 rows
# Second 462: 60 rows
# Second 463: 60 rows
# Second 464: 60 rows
# Second 465: 60 rows
# Second 466: 60 rows
# Second 467: 60 rows
# Second 468: 60 rows
# Second 469: 60 rows
# Second 470: 60 rows
# Second 471: 60 rows
# Second 472: 60 rows
# Second 473: 60 rows
# Second 474: 60 rows
# Second 475: 60 rows
# Second 476: 60 rows
# Second 477: 60 rows
# Second 478: 60 rows
# Second 479: 60 rows
# Second 480: 60 rows
# Second 481: 60 rows
# Second 482: 60 rows
# Second 483: 60 rows
# Second 484: 60 rows
# Second 485: 60 rows
# Second 486: 60 rows
# Second 487: 60 rows
# Second 488: 60 rows
# Second 489: 60 rows
# Second 490: 60 rows
# Second 491: 60 rows
# Second 492: 60 rows
# Second 493: 60 rows
# Second 494: 60 rows
# Second 495: 60 rows
# Second 496: 60 rows
# Second 497: 60 rows
# Second 498: 60 rows
# Second 499: 60 rows
# Second 500: 60 rows
# Second 501: 60 rows
# Second 502: 60 rows
# Second 503: 60 rows
# Second 504: 60 rows
# Second 505: 60 rows
# Second 506: 60 rows
# Second 507: 60 rows
# Second 508: 60 rows
# Second 509: 60 rows
# Second 510: 60 rows
# Second 511: 60 rows
# Second 512: 60 rows
# Second 513: 60 rows
# Second 514: 60 rows
# Second 515: 60 rows
# Second 516: 60 rows
# Second 517: 60 rows
# Second 518: 60 rows
# Second 519: 60 rows
# Second 520: 60 rows
# Second 521: 60 rows
# Second 522: 60 rows
# Second 523: 60 rows
# Second 524: 60 rows
# Second 525: 60 rows
# Second 526: 60 rows
# Second 527: 60 rows
# Second 528: 60 rows
# Second 529: 60 rows
# Second 530: 60 rows
# Second 531: 60 rows
# Second 532: 60 rows
# Second 533: 60 rows
# Second 534: 60 rows
# Second 535: 60 rows
# Second 536: 60 rows
# Second 537: 60 rows
# Second 538: 60 rows
# Second 539: 60 rows
# Second 540: 60 rows
# Second 541: 60 rows
# Second 542: 60 rows
# Second 543: 60 rows
# Second 544: 60 rows
# Second 545: 60 rows
# Second 546: 60 rows
# Second 547: 60 rows
# Second 548: 60 rows
# Second 549: 60 rows
# Second 550: 60 rows
# Second 551: 60 rows
# Second 552: 60 rows
# Second 553: 60 rows
# Second 554: 60 rows
# Second 555: 60 rows
# Second 556: 60 rows
# Second 557: 60 rows
# Second 558: 60 rows
# Second 559: 60 rows
# Second 560: 60 rows
# Second 561: 60 rows
# Second 562: 60 rows
# Second 563: 60 rows
# Second 564: 60 rows
# Second 565: 60 rows
# Second 566: 60 rows
# Second 567: 60 rows
# Second 568: 60 rows
# Second 569: 60 rows
# Second 570: 60 rows
# Second 571: 60 rows
# Second 572: 60 rows
# Second 573: 60 rows
# Second 574: 60 rows
# Second 575: 60 rows
# Second 576: 60 rows
# Second 577: 60 rows
# Second 578: 60 rows
# Second 579: 60 rows
# Second 580: 60 rows
# Second 581: 60 rows
# Second 582: 60 rows
# Second 583: 60 rows
# Second 584: 60 rows
# Second 585: 60 rows
# Second 586: 60 rows
# Second 587: 60 rows
# Second 588: 60 rows
# Second 589: 60 rows
# Second 590: 60 rows
# Second 591: 60 rows
# Second 592: 60 rows
# Second 593: 60 rows
# Second 594: 60 rows
# Second 595: 60 rows
# Second 596: 60 rows
# Second 597: 60 rows
# Second 598: 60 rows
# Second 599: 60 rows
# Second 600: 60 rows
# Second 601: 60 rows
# Second 602: 60 rows
# Second 603: 60 rows
# Second 604: 60 rows
# Second 605: 60 rows
# Second 606: 60 rows
# Second 607: 60 rows
# Second 608: 60 rows
# Second 609: 60 rows
# Second 610: 60 rows
# Second 611: 60 rows
# Second 612: 60 rows
# Second 613: 60 rows
# Second 614: 60 rows
# Second 615: 60 rows
# Second 616: 60 rows
# Second 617: 60 rows
# Second 618: 60 rows
# Second 619: 60 rows
# Second 620: 60 rows
# Second 621: 60 rows
# Second 622: 60 rows
# Second 623: 60 rows
# Second 624: 60 rows
# Second 625: 60 rows
# Second 626: 60 rows
# Second 627: 60 rows
# Second 628: 60 rows
# Second 629: 60 rows
# Second 630: 60 rows
# Second 631: 60 rows
# Second 632: 60 rows
# Second 633: 60 rows
# Second 634: 60 rows
# Second 635: 60 rows
# Second 636: 60 rows
# Second 637: 60 rows
# Second 638: 60 rows
# Second 639: 60 rows
# Second 640: 60 rows
# Second 641: 60 rows
# Second 642: 60 rows
# Second 643: 60 rows
# Second 644: 60 rows
# Second 645: 60 rows
# Second 646: 60 rows
# Second 647: 60 rows
# Second 648: 60 rows
# Second 649: 60 rows
# Second 650: 60 rows
# Second 651: 60 rows
# Second 652: 60 rows
# Second 653: 60 rows
# Second 654: 60 rows
# Second 655: 60 rows
# Second 656: 60 rows
# Second 657: 60 rows
# Second 658: 60 rows
# Second 659: 60 rows
# Second 660: 60 rows
# Second 661: 60 rows
# Second 662: 60 rows
# Second 663: 60 rows
# Second 664: 60 rows
# Second 665: 60 rows
# Second 666: 60 rows
# Second 667: 60 rows
# Second 668: 60 rows
# Second 669: 60 rows
# Second 670: 60 rows
# Second 671: 60 rows
# Second 672: 60 rows
# Second 673: 60 rows
# Second 674: 60 rows
# Second 675: 60 rows
# Second 676: 60 rows
# Second 677: 60 rows
# Second 678: 60 rows
# Second 679: 60 rows
# Second 680: 60 rows
# Second 681: 60 rows
# Second 682: 60 rows
# Second 683: 60 rows
# Second 684: 60 rows
# Second 685: 60 rows
# Second 686: 60 rows
# Second 687: 60 rows
# Second 688: 60 rows
# Second 689: 60 rows
# Second 690: 60 rows
# Second 691: 60 rows
# Second 692: 60 rows
# Second 693: 60 rows
# Second 694: 60 rows
# Second 695: 60 rows
# Second 696: 60 rows
# Second 697: 60 rows
# Second 698: 60 rows
# Second 699: 60 rows
# Second 700: 60 rows
# Second 701: 60 rows
# Second 702: 60 rows
# Second 703: 60 rows
# Second 704: 60 rows
# Second 705: 60 rows
# Second 706: 60 rows
# Second 707: 60 rows
# Second 708: 60 rows
# Second 709: 60 rows
# Second 710: 60 rows
# Second 711: 60 rows
# Second 712: 60 rows
# Second 713: 60 rows
# Second 714: 60 rows
# Second 715: 60 rows
# Second 716: 60 rows
# Second 717: 60 rows
# Second 718: 60 rows
# Second 719: 60 rows
# Second 720: 60 rows
# Second 721: 60 rows
# Second 722: 60 rows
# Second 723: 60 rows
# Second 724: 60 rows
# Second 725: 60 rows
# Second 726: 60 rows
# Second 727: 60 rows
# Second 728: 60 rows
# Second 729: 60 rows
# Second 730: 60 rows
# Second 731: 60 rows
# Second 732: 60 rows
# Second 733: 60 rows
# Second 734: 60 rows
# Second 735: 60 rows
# Second 736: 60 rows
# Second 737: 60 rows
# Second 738: 60 rows
# Second 739: 60 rows
# Second 740: 60 rows
# Second 741: 60 rows
# Second 742: 60 rows
# Second 743: 60 rows
# Second 744: 60 rows
# Second 745: 60 rows
# Second 746: 60 rows
# Second 747: 60 rows
# Second 748: 60 rows
# Second 749: 60 rows
# Second 750: 60 rows
# Second 751: 60 rows
# Second 752: 60 rows
# Second 753: 60 rows
# Second 754: 60 rows
# Second 755: 60 rows
# Second 756: 60 rows
# Second 757: 60 rows
# Second 758: 60 rows
# Second 759: 60 rows
# Second 760: 60 rows
# Second 761: 60 rows
# Second 762: 60 rows
# Second 763: 60 rows
# Second 764: 60 rows
# Second 765: 60 rows
# Second 766: 60 rows
# Second 767: 60 rows
# Second 768: 60 rows
# Second 769: 60 rows
# Second 770: 60 rows
# Second 771: 60 rows
# Second 772: 60 rows
# Second 773: 60 rows
# Second 774: 60 rows
# Second 775: 60 rows
# Second 776: 60 rows
# Second 777: 60 rows
# Second 778: 60 rows
# Second 779: 60 rows
# Second 780: 60 rows
# Second 781: 60 rows
# Second 782: 60 rows
# Second 783: 60 rows
# Second 784: 60 rows
# Second 785: 60 rows
# Second 786: 60 rows
# Second 787: 60 rows
# Second 788: 60 rows
# Second 789: 60 rows
# Second 790: 60 rows
# Second 791: 60 rows
# Second 792: 60 rows
# Second 793: 60 rows
# Second 794: 60 rows
# Second 795: 60 rows
# Second 796: 60 rows
# Second 797: 60 rows
# Second 798: 60 rows
# Second 799: 60 rows
# Second 800: 60 rows
# Second 801: 60 rows
# Second 802: 60 rows
# Second 803: 60 rows
# Second 804: 60 rows
# Second 805: 60 rows
# Second 806: 60 rows
# Second 807: 60 rows
# Second 808: 60 rows
# Second 809: 60 rows
# Second 810: 60 rows
# Second 811: 60 rows
# Second 812: 60 rows
# Second 813: 60 rows
# Second 814: 60 rows
# Second 815: 60 rows
# Second 816: 60 rows
# Second 817: 60 rows
# Second 818: 60 rows
# Second 819: 60 rows
# Second 820: 60 rows
# Second 821: 60 rows
# Second 822: 60 rows
# Second 823: 60 rows
# Second 824: 60 rows
# Second 825: 60 rows
# Second 826: 60 rows
# Second 827: 60 rows
# Second 828: 60 rows
# Second 829: 60 rows
# Second 830: 60 rows
# Second 831: 60 rows
# Second 832: 60 rows
# Second 833: 60 rows
# Second 834: 60 rows
# Second 835: 60 rows
# Second 836: 60 rows
# Second 837: 60 rows
# Second 838: 60 rows
# Second 839: 60 rows
# Second 840: 60 rows
# Second 841: 60 rows
# Second 842: 60 rows
# Second 843: 60 rows
# Second 844: 60 rows
# Second 845: 60 rows
# Second 846: 60 rows
# Second 847: 60 rows
# Second 848: 60 rows
# Second 849: 60 rows
# Second 850: 60 rows
# Second 851: 60 rows
# Second 852: 60 rows
# Second 853: 60 rows
# Second 854: 60 rows
# Second 855: 60 rows
# Second 856: 60 rows
# Second 857: 60 rows
# Second 858: 60 rows
# Second 859: 60 rows
# Second 860: 60 rows
# Second 861: 60 rows
# Second 862: 60 rows
# Second 863: 60 rows
# Second 864: 60 rows
# Second 865: 60 rows
# Second 866: 60 rows
# Second 867: 60 rows
# Second 868: 60 rows
# Second 869: 60 rows
# Second 870: 60 rows
# Second 871: 60 rows
# Second 872: 60 rows
# Second 873: 60 rows
# Second 874: 60 rows
# Second 875: 60 rows
# Second 876: 60 rows
# Second 877: 60 rows
# Second 878: 60 rows
# Second 879: 60 rows
# Second 880: 60 rows
# Second 881: 60 rows
# Second 882: 60 rows
# Second 883: 60 rows
# Second 884: 60 rows
# Second 885: 60 rows
# Second 886: 60 rows
# Second 887: 60 rows
# Second 888: 60 rows
# Second 889: 60 rows
# Second 890: 60 rows
# Second 891: 60 rows
# Second 892: 60 rows
# Second 893: 60 rows
# Second 894: 60 rows
# Second 895: 60 rows
# Second 896: 60 rows
# Second 897: 60 rows
# Second 898: 60 rows
# Second 899: 60 rows
# Second 900: 60 rows
# Second 901: 60 rows
# Second 902: 60 rows
# Second 903: 60 rows
# Second 904: 60 rows
# Second 905: 60 rows
# Second 906: 60 rows
# Second 907: 60 rows
# Second 908: 60 rows
# Second 909: 60 rows
# Second 910: 60 rows
# Second 911: 60 rows
# Second 912: 60 rows
# Second 913: 60 rows
# Second 914: 60 rows
# Second 915: 60 rows
# Second 916: 60 rows
# Second 917: 60 rows
# Second 918: 60 rows
# Second 919: 60 rows
# Second 920: 60 rows
# Second 921: 60 rows
# Second 922: 60 rows
# Second 923: 60 rows
# Second 924: 60 rows
# Second 925: 60 rows
# Second 926: 60 rows
# Second 927: 60 rows
# Second 928: 60 rows
# Second 929: 60 rows
# Second 930: 60 rows
# Second 931: 60 rows
# Second 932: 60 rows
# Second 933: 60 rows
# Second 934: 60 rows
# Second 935: 60 rows
# Second 936: 60 rows
# Second 937: 60 rows
# Second 938: 60 rows
# Second 939: 60 rows
# Second 940: 60 rows
# Second 941: 60 rows
# Second 942: 60 rows
# Second 943: 60 rows
# Second 944: 60 rows
# Second 945: 60 rows
# Second 946: 60 rows
# Second 947: 60 rows
# Second 948: 60 rows
# Second 949: 60 rows
# Second 950: 60 rows
# Second 951: 60 rows
# Second 952: 60 rows
# Second 953: 60 rows
# Second 954: 60 rows
# Second 955: 60 rows
# Second 956: 60 rows
# Second 957: 60 rows
# Second 958: 60 rows
# Second 959: 60 rows
# Second 960: 60 rows
# Second 961: 60 rows
# Second 962: 60 rows
# Second 963: 60 rows
# Second 964: 60 rows
# Second 965: 60 rows
# Second 966: 60 rows
# Second 967: 60 rows
# Second 968: 60 rows
# Second 969: 60 rows
# Second 970: 60 rows
# Second 971: 60 rows
# Second 972: 60 rows
# Second 973: 60 rows
# Second 974: 60 rows
# Second 975: 60 rows
# Second 976: 60 rows
# Second 977: 60 rows
# Second 978: 60 rows
# Second 979: 60 rows
# Second 980: 60 rows
# Second 981: 60 rows
# Second 982: 60 rows
# Second 983: 60 rows
# Second 984: 60 rows
# Second 985: 60 rows
# Second 986: 60 rows
# Second 987: 60 rows
# Second 988: 60 rows
# Second 989: 60 rows
# Second 990: 60 rows
# Second 991: 60 rows
# Second 992: 60 rows
# Second 993: 60 rows
# Second 994: 60 rows
# Second 995: 60 rows
# Second 996: 60 rows
# Second 997: 60 rows
# Second 998: 60 rows
# Second 999: 60 rows
# Second 1000: 60 rows
# Second 1001: 60 rows
# Second 1002: 60 rows
# Second 1003: 60 rows
# Second 1004: 60 rows
# Second 1005: 60 rows
# Second 1006: 60 rows
# Second 1007: 60 rows
# Second 1008: 60 rows
# Second 1009: 60 rows
# Second 1010: 60 rows
# Second 1011: 60 rows
# Second 1012: 60 rows
# Second 1013: 60 rows
# Second 1014: 60 rows
# Second 1015: 60 rows
# Second 1016: 60 rows
# Second 1017: 60 rows
# Second 1018: 60 rows
# Second 1019: 60 rows
# Second 1020: 60 rows
# Second 1021: 60 rows
# Second 1022: 60 rows
# Second 1023: 60 rows
# Second 1024: 60 rows
# Second 1025: 60 rows
# Second 1026: 60 rows
# Second 1027: 60 rows
# Second 1028: 60 rows
# Second 1029: 60 rows
# Second 1976: 60 rows
# Second 1977: 60 rows
# Second 1978: 60 rows
# Second 1979: 60 rows
# Second 1980: 60 rows
# Second 1981: 60 rows
# Second 1982: 60 rows
# Second 1983: 60 rows
# Second 1984: 60 rows
# Second 1985: 60 rows
# Second 1986: 60 rows
# Second 1987: 60 rows
# Second 1988: 60 rows
# Second 1989: 60 rows
# Second 1990: 60 rows
# Second 1991: 60 rows
# Second 1992: 60 rows
# Second 1993: 60 rows
# Second 1994: 60 rows
# Second 1995: 60 rows
# Second 1996: 60 rows
# Second 1997: 60 rows
# Second 1998: 60 rows
# Second 1999: 60 rows
# Second 2000: 60 rows
# Second 2001: 60 rows
# Second 2002: 60 rows
# Second 2003: 60 rows
# Second 2004: 60 rows
# Second 2005: 60 rows
# Second 2006: 60 rows
# Second 2007: 60 rows
# Second 2008: 60 rows
# Second 2009: 60 rows
# Second 2010: 60 rows
# Second 2011: 60 rows
# Second 2012: 60 rows
# Second 2013: 60 rows
# Second 2014: 60 rows
# Second 2015: 60 rows
# Second 2016: 60 rows
# Second 2017: 60 rows
# Second 2018: 60 rows
# Second 2019: 60 rows
# Second 2020: 60 rows
# Second 2021: 60 rows
# Second 2022: 60 rows
# Second 2023: 60 rows
# Second 2024: 60 rows
# Second 2025: 60 rows
# Second 2026: 60 rows
# Second 2027: 60 rows
# Second 2028: 60 rows
# Second 2029: 60 rows
# Second 2030: 60 rows
# Second 2031: 60 rows
# Second 2032: 60 rows
# Second 2033: 60 rows
# Second 2034: 60 rows
# Second 2035: 60 rows
# Second 2036: 60 rows
# Second 2037: 60 rows
# Second 2038: 60 rows
# Second 2039: 60 rows
# Second 2040: 60 rows
# Second 2041: 60 rows
# Second 2042: 60 rows
# Second 2043: 60 rows
# Second 2044: 60 rows
# Second 2045: 60 rows
# Second 2046: 60 rows
# Second 2047: 60 rows
# Second 2048: 60 rows
# Second 2049: 60 rows
# Second 2050: 60 rows
# Second 2051: 60 rows
# Second 2052: 60 rows
# Second 2053: 60 rows
# Second 2054: 60 rows
# Second 2055: 60 rows
# Second 2056: 60 rows
# Second 2057: 60 rows
# Second 2058: 60 rows
# Second 2059: 60 rows
# Second 2060: 60 rows
# Second 2061: 60 rows
# Second 2062: 60 rows
# Second 2063: 60 rows
# Second 2064: 60 rows
# Second 2065: 60 rows
# Second 2066: 60 rows
# Second 2067: 60 rows
# Second 2068: 60 rows
# Second 2069: 60 rows
# Second 2070: 60 rows
# Second 2071: 60 rows
# Second 2072: 60 rows
# Second 2073: 60 rows
# Second 2074: 60 rows
# Second 2075: 60 rows
# Second 2076: 60 rows
# Second 2077: 60 rows
# Second 2078: 60 rows
# Second 2079: 60 rows
# Second 2080: 60 rows
# Second 2081: 60 rows
# Second 2082: 60 rows
# Second 2083: 60 rows
# Second 2084: 60 rows
# Second 2085: 60 rows
# Second 2086: 60 rows
# Second 2087: 60 rows
# Second 2088: 60 rows
# Second 2089: 60 rows
# Second 2090: 60 rows
# Second 2091: 60 rows
# Second 2092: 60 rows
# Second 2093: 60 rows
# Second 2094: 60 rows
# Second 2687: 60 rows
# Second 2688: 60 rows
# Second 2689: 60 rows
# Second 2690: 60 rows
# Second 2691: 60 rows
# Second 2692: 60 rows
# Second 2693: 60 rows
# Second 2694: 60 rows
# Second 2695: 60 rows
# Second 2696: 60 rows
# Second 2697: 60 rows
# Second 2698: 60 rows
# Second 2699: 60 rows
# Second 2700: 60 rows
# Second 2701: 60 rows
# Second 2702: 60 rows
# Second 2703: 60 rows
# Second 2704: 60 rows
# Second 2705: 60 rows
# Second 2706: 60 rows
# Second 2707: 60 rows
# Second 2708: 60 rows
# Second 2709: 60 rows
# Second 2710: 60 rows
# Second 2711: 60 rows
# Second 2712: 60 rows
# Second 2713: 60 rows

# %% [markdown]
# Delete even rows and then delete random rows until it reaches 60 rows per second

# %%
import csv
import random

def delete_rows_to_reach_60(labels_file, output_file):
    rows_per_second = {}

    with open(labels_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            rec_time = row['rec_time']
            time_parts = rec_time.split(':')
            minute = int(time_parts[0])
            second_micro = time_parts[1].split('.')
            second = int(second_micro[0])
            microsecond = int(second_micro[1])

            total_microseconds = (minute * 60 + second) * 1000000 + microsecond
            second = total_microseconds // 1000000

            if second in rows_per_second:
                rows_per_second[second].append(row)  # Store the row
            else:
                rows_per_second[second] = [row]  # Create a new list for the second

    # Delete even rows for each second
    for second, rows in rows_per_second.items():
        if len(rows) > 60:
            rows_per_second[second] = [row for i, row in enumerate(rows) if i % 2 == 0]

    # Delete additional rows randomly to reach 60 rows
    for second, rows in rows_per_second.items():
        if len(rows) > 60:
            rows_to_delete = len(rows) - 60
            random_indices = random.sample(range(len(rows)), rows_to_delete)  # Generate random indices to delete
            random_indices.sort(reverse=True)  # Sort in reverse order for deleting rows without altering the order

            for index in random_indices:
                del rows[index]  # Delete rows at the specified indices

    # Write the modified data to a new CSV file
    fieldnames = reader.fieldnames
    with open(output_file, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()

        for rows in rows_per_second.values():
            writer.writerows(rows)

    print(f"Modified data written to {output_file}")

for x in range(12,13):
  x=str(x)
  labels_file = '/content/drive/MyDrive/Data/Eye_Tracker/'+x+'_M_Labels.csv'
  output_file = '/content/drive/MyDrive/Data/Eye_Tracker/'+x+'_M_LabelsU.csv'
  delete_rows_to_reach_60(labels_file, output_file)
# Out:
# Modified data written to /content/drive/MyDrive/Data/Eye_Tracker/12_M_LabelsU.csv

# %% [markdown]
# Join videos if needed

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.27.1)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.22.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)

# %%
from moviepy.editor import VideoFileClip, concatenate

def combine_videos(video1_path, video2_path, output_path):
    # Load the videos
    video1 = VideoFileClip(video1_path)
    video2 = VideoFileClip(video2_path)

    # Concatenate the videos
    final_video = concatenate([video1, video2])

    # Save the output video to the specified path
    final_video.write_videofile(output_path, codec='libx264')

# Example usage
video1_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_1. Recording 2023-05-17 34035 PM_Dikablis Glasses 3_Eye Cam - Left.mp4'
video2_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_2. Recording 2023-05-17 35045 PM_Dikablis Glasses 3_Eye Cam - Left.mp4'
video3_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_3. Recording 2023-05-17 40048 PM_Dikablis Glasses 3_Eye Cam - Left.mp4'
video4_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_4. Recording 2023-05-17 41051 PM_Dikablis Glasses 3_Eye Cam - Left.mp4'
video5_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_5. Recording 2023-05-17 42053 PM_Dikablis Glasses 3_Eye Cam - Left.mp4'

output_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Left.mp4'

combine_videos(video1_path, video2_path,video3_path,video4_path,video5_path, output_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d005d1bc02a4> in <cell line: 23>()
#      21 output_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Left.mp4'
#      22
# ---> 23 combine_videos(video1_path, video2_path,video3_path,video4_path,video5_path, output_path)
#
# TypeError: combine_videos() takes 3 positional arguments but 6 were given

# %% [markdown]
# Combine more than 2 videos

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips

def combine_videos(video_paths, output_path):
    # Load the videos
    videos = [VideoFileClip(path) for path in video_paths]

    # Concatenate the videos
    final_video = concatenate_videoclips(videos)

    # Save the output video to the specified path
    final_video.write_videofile(output_path, codec='libx264')

# Example usage
video_paths = [
    '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_1. Recording 2023-05-17 34035 PM_Dikablis Glasses 3_Eye Cam - Right.mp4',
    '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_2. Recording 2023-05-17 35045 PM_Dikablis Glasses 3_Eye Cam - Right.mp4',
    '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_3. Recording 2023-05-17 40048 PM_Dikablis Glasses 3_Eye Cam - Right.mp4',
    '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_4. Recording 2023-05-17 41051 PM_Dikablis Glasses 3_Eye Cam - Right.mp4',
    '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_5. Recording 2023-05-17 42053 PM_Dikablis Glasses 3_Eye Cam - Right.mp4'
]

output_path = '/content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Right.mp4'

combine_videos(video_paths, output_path)
# Out:
# t:  26%|██▌       | 41704/162768 [1:08:34<11:43, 171.98it/s, now=None]
#
# t:  68%|██████▊   | 110460/162768 [1:00:33<11:16, 77.28it/s, now=None]
#
#
#
# t:  26%|██▌       | 41704/162768 [1:08:34<11:43, 171.98it/s, now=None]
#
# t:  68%|██████▊   | 110460/162768 [1:00:33<11:16, 77.28it/s, now=None]
# t:   1%|          | 1362/162768 [1:02:07<16:44, 160.65it/s, now=None]
# Moviepy - Building video /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Right.mp4.
# Moviepy - Writing video /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Right.mp4
# Streaming output truncated to the last 5000 lines.
# t:  89%|████████▊ | 144424/162768 [25:08<03:28, 88.07it/s, now=None]
#
#
# t:  89%|████████▊ | 144435/162768 [25:08<03:17, 92.75it/s, now=None]
#
#
# t:  89%|████████▊ | 144445/162768 [25:08<03:27, 88.22it/s, now=None]
#
#
# t:  89%|████████▊ | 144454/162768 [25:08<03:40, 82.90it/s, now=None]
#
#
# t:  89%|████████▉ | 144463/162768 [25:09<03:48, 80.06it/s, now=None]
#
#
# t:  89%|████████▉ | 144472/162768 [25:09<03:47, 80.30it/s, now=None]
#
#
# t:  89%|████████▉ | 144481/162768 [25:09<03:42, 82.01it/s, now=None]
#
#
# t:  89%|████████▉ | 144490/162768 [25:09<03:49, 79.49it/s, now=None]
#
#
# t:  89%|████████▉ | 144500/162768 [25:09<03:40, 82.95it/s, now=None]
#
#
# t:  89%|████████▉ | 144509/162768 [25:09<03:50, 79.35it/s, now=None]
#
#
# t:  89%|████████▉ | 144519/162768 [25:09<03:40, 82.66it/s, now=None]
#
#
# t:  89%|████████▉ | 144528/162768 [25:09<03:49, 79.36it/s, now=None]
#
#
# t:  89%|████████▉ | 144537/162768 [25:10<03:48, 79.84it/s, now=None]
#
#
# t:  89%|████████▉ | 144546/162768 [25:10<03:43, 81.52it/s, now=None]
#
#
# t:  89%|████████▉ | 144556/162768 [25:10<03:34, 85.08it/s, now=None]
#
#
# t:  89%|████████▉ | 144565/162768 [25:10<03:41, 82.02it/s, now=None]
#
#
# t:  89%|████████▉ | 144574/162768 [25:10<03:41, 82.12it/s, now=None]
#
#
# t:  89%|████████▉ | 144583/162768 [25:10<03:38, 83.34it/s, now=None]
#
#
# t:  89%|████████▉ | 144595/162768 [25:10<03:15, 93.17it/s, now=None]
#
#
# t:  89%|████████▉ | 144605/162768 [25:10<03:27, 87.55it/s, now=None]
#
#
# t:  89%|████████▉ | 144618/162768 [25:10<03:06, 97.38it/s, now=None]
#
#
# t:  89%|████████▉ | 144630/162768 [25:11<02:57, 102.47it/s, now=None]
#
#
# t:  89%|████████▉ | 144643/162768 [25:11<02:44, 109.98it/s, now=None]
#
#
# t:  89%|████████▉ | 144656/162768 [25:11<02:40, 113.09it/s, now=None]
#
#
# t:  89%|████████▉ | 144668/162768 [25:11<02:39, 113.23it/s, now=None]
#
#
# t:  89%|████████▉ | 144683/162768 [25:11<02:26, 123.38it/s, now=None]
#
#
# t:  89%|████████▉ | 144696/162768 [25:11<02:29, 120.80it/s, now=None]
#
#
# t:  89%|████████▉ | 144709/162768 [25:11<02:27, 122.55it/s, now=None]
#
#
# t:  89%|████████▉ | 144722/162768 [25:11<02:26, 123.05it/s, now=None]
#
#
# t:  89%|████████▉ | 144735/162768 [25:11<02:25, 123.80it/s, now=None]
#
#
# t:  89%|████████▉ | 144748/162768 [25:11<02:25, 124.20it/s, now=None]
#
#
# t:  89%|████████▉ | 144761/162768 [25:12<02:26, 122.64it/s, now=None]
#
#
# t:  89%|████████▉ | 144774/162768 [25:12<02:27, 121.78it/s, now=None]
#
#
# t:  89%|████████▉ | 144787/162768 [25:12<02:29, 120.47it/s, now=None]
#
#
# t:  89%|████████▉ | 144801/162768 [25:12<02:23, 125.42it/s, now=None]
#
#
# t:  89%|████████▉ | 144814/162768 [25:12<02:30, 119.31it/s, now=None]
#
#
# t:  89%|████████▉ | 144827/162768 [25:12<02:28, 120.99it/s, now=None]
#
#
# t:  89%|████████▉ | 144842/162768 [25:12<02:20, 127.75it/s, now=None]
#
#
# t:  89%|████████▉ | 144855/162768 [25:12<02:23, 125.25it/s, now=None]
#
#
# t:  89%|████████▉ | 144868/162768 [25:12<02:23, 124.53it/s, now=None]
#
#
# t:  89%|████████▉ | 144881/162768 [25:13<02:26, 122.23it/s, now=None]
#
#
# t:  89%|████████▉ | 144894/162768 [25:13<02:32, 116.89it/s, now=None]
#
#
# t:  89%|████████▉ | 144906/162768 [25:13<02:41, 110.86it/s, now=None]
#
#
# t:  89%|████████▉ | 144919/162768 [25:13<02:34, 115.51it/s, now=None]
#
#
# t:  89%|████████▉ | 144932/162768 [25:13<02:29, 119.11it/s, now=None]
#
#
# t:  89%|████████▉ | 144945/162768 [25:13<02:29, 119.43it/s, now=None]
#
#
# t:  89%|████████▉ | 144958/162768 [25:13<02:29, 119.40it/s, now=None]
#
#
# t:  89%|████████▉ | 144970/162768 [25:13<02:29, 119.43it/s, now=None]
#
#
# t:  89%|████████▉ | 144984/162768 [25:13<02:23, 123.92it/s, now=None]
#
#
# t:  89%|████████▉ | 144997/162768 [25:14<02:26, 120.94it/s, now=None]
#
#
# t:  89%|████████▉ | 145011/162768 [25:14<02:24, 122.85it/s, now=None]
#
#
# t:  89%|████████▉ | 145024/162768 [25:14<02:26, 121.23it/s, now=None]
#
#
# t:  89%|████████▉ | 145037/162768 [25:14<02:27, 120.58it/s, now=None]
#
#
# t:  89%|████████▉ | 145052/162768 [25:14<02:18, 128.34it/s, now=None]
#
#
# t:  89%|████████▉ | 145065/162768 [25:14<02:20, 126.02it/s, now=None]
#
#
# t:  89%|████████▉ | 145078/162768 [25:14<02:22, 124.10it/s, now=None]
#
#
# t:  89%|████████▉ | 145091/162768 [25:14<02:20, 125.74it/s, now=None]
#
#
# t:  89%|████████▉ | 145104/162768 [25:14<02:26, 120.42it/s, now=None]
#
#
# t:  89%|████████▉ | 145117/162768 [25:15<02:29, 118.31it/s, now=None]
#
#
# t:  89%|████████▉ | 145131/162768 [25:15<02:25, 121.14it/s, now=None]
#
#
# t:  89%|████████▉ | 145144/162768 [25:15<02:32, 115.31it/s, now=None]
#
#
# t:  89%|████████▉ | 145159/162768 [25:15<02:22, 123.23it/s, now=None]
#
#
# t:  89%|████████▉ | 145173/162768 [25:15<02:18, 127.14it/s, now=None]
#
#
# t:  89%|████████▉ | 145186/162768 [25:15<02:25, 120.64it/s, now=None]
#
#
# t:  89%|████████▉ | 145200/162768 [25:15<02:23, 122.59it/s, now=None]
#
#
# t:  89%|████████▉ | 145213/162768 [25:15<02:25, 120.47it/s, now=None]
#
#
# t:  89%|████████▉ | 145227/162768 [25:15<02:20, 125.27it/s, now=None]
#
#
# t:  89%|████████▉ | 145240/162768 [25:15<02:18, 126.16it/s, now=None]
#
#
# t:  89%|████████▉ | 145254/162768 [25:16<02:14, 129.89it/s, now=None]
#
#
# t:  89%|████████▉ | 145268/162768 [25:16<02:13, 130.96it/s, now=None]
#
#
# t:  89%|████████▉ | 145282/162768 [25:16<02:21, 123.93it/s, now=None]
#
#
# t:  89%|████████▉ | 145298/162768 [25:16<02:13, 131.35it/s, now=None]
#
#
# t:  89%|████████▉ | 145312/162768 [25:16<02:14, 129.48it/s, now=None]
#
#
# t:  89%|████████▉ | 145326/162768 [25:16<02:17, 127.29it/s, now=None]
#
#
# t:  89%|████████▉ | 145340/162768 [25:16<02:13, 130.14it/s, now=None]
#
#
# t:  89%|████████▉ | 145354/162768 [25:16<02:12, 131.39it/s, now=None]
#
#
# t:  89%|████████▉ | 145368/162768 [25:16<02:15, 128.03it/s, now=None]
#
#
# t:  89%|████████▉ | 145382/162768 [25:17<02:13, 130.45it/s, now=None]
#
#
# t:  89%|████████▉ | 145397/162768 [25:17<02:09, 133.63it/s, now=None]
#
#
# t:  89%|████████▉ | 145411/162768 [25:17<02:18, 124.92it/s, now=None]
#
#
# t:  89%|████████▉ | 145426/162768 [25:17<02:13, 129.65it/s, now=None]
#
#
# t:  89%|████████▉ | 145440/162768 [25:17<02:12, 130.95it/s, now=None]
#
#
# t:  89%|████████▉ | 145454/162768 [25:17<02:12, 130.83it/s, now=None]
#
#
# t:  89%|████████▉ | 145468/162768 [25:17<02:11, 131.98it/s, now=None]
#
#
# t:  89%|████████▉ | 145482/162768 [25:17<02:09, 133.99it/s, now=None]
#
#
# t:  89%|████████▉ | 145496/162768 [25:17<02:14, 128.19it/s, now=None]
#
#
# t:  89%|████████▉ | 145510/162768 [25:18<02:13, 129.53it/s, now=None]
#
#
# t:  89%|████████▉ | 145524/162768 [25:18<02:14, 128.04it/s, now=None]
#
#
# t:  89%|████████▉ | 145538/162768 [25:18<02:12, 130.37it/s, now=None]
#
#
# t:  89%|████████▉ | 145552/162768 [25:18<02:13, 128.75it/s, now=None]
#
#
# t:  89%|████████▉ | 145565/162768 [25:18<02:15, 126.97it/s, now=None]
#
#
# t:  89%|████████▉ | 145578/162768 [25:18<02:14, 127.36it/s, now=None]
#
#
# t:  89%|████████▉ | 145591/162768 [25:18<02:16, 126.13it/s, now=None]
#
#
# t:  89%|████████▉ | 145604/162768 [25:18<02:14, 127.17it/s, now=None]
#
#
# t:  89%|████████▉ | 145617/162768 [25:18<02:21, 120.90it/s, now=None]
#
#
# t:  89%|████████▉ | 145630/162768 [25:19<02:18, 123.35it/s, now=None]
#
#
# t:  89%|████████▉ | 145643/162768 [25:19<02:20, 122.30it/s, now=None]
#
#
# t:  89%|████████▉ | 145656/162768 [25:19<02:17, 124.22it/s, now=None]
#
#
# t:  89%|████████▉ | 145671/162768 [25:19<02:14, 127.26it/s, now=None]
#
#
# t:  90%|████████▉ | 145684/162768 [25:19<02:22, 120.26it/s, now=None]
#
#
# t:  90%|████████▉ | 145699/162768 [25:19<02:14, 127.28it/s, now=None]
#
#
# t:  90%|████████▉ | 145712/162768 [25:19<02:17, 124.10it/s, now=None]
#
#
# t:  90%|████████▉ | 145725/162768 [25:19<02:15, 125.38it/s, now=None]
#
#
# t:  90%|████████▉ | 145738/162768 [25:19<02:14, 126.27it/s, now=None]
#
#
# t:  90%|████████▉ | 145751/162768 [25:19<02:15, 125.90it/s, now=None]
#
#
# t:  90%|████████▉ | 145764/162768 [25:20<02:14, 126.27it/s, now=None]
#
#
# t:  90%|████████▉ | 145779/162768 [25:20<02:10, 130.54it/s, now=None]
#
#
# t:  90%|████████▉ | 145793/162768 [25:20<02:09, 131.55it/s, now=None]
#
#
# t:  90%|████████▉ | 145807/162768 [25:20<02:11, 128.89it/s, now=None]
#
#
# t:  90%|████████▉ | 145821/162768 [25:20<02:08, 131.41it/s, now=None]
#
#
# t:  90%|████████▉ | 145835/162768 [25:20<02:10, 129.39it/s, now=None]
#
#
# t:  90%|████████▉ | 145848/162768 [25:20<02:12, 127.80it/s, now=None]
#
#
# t:  90%|████████▉ | 145862/162768 [25:20<02:11, 128.09it/s, now=None]
#
#
# t:  90%|████████▉ | 145875/162768 [25:20<02:25, 115.71it/s, now=None]
#
#
# t:  90%|████████▉ | 145887/162768 [25:21<02:38, 106.26it/s, now=None]
#
#
# t:  90%|████████▉ | 145898/162768 [25:21<02:50, 99.19it/s, now=None]
#
#
# t:  90%|████████▉ | 145909/162768 [25:21<02:59, 93.67it/s, now=None]
#
#
# t:  90%|████████▉ | 145919/162768 [25:21<03:11, 87.93it/s, now=None]
#
#
# t:  90%|████████▉ | 145928/162768 [25:21<03:12, 87.69it/s, now=None]
#
#
# t:  90%|████████▉ | 145937/162768 [25:21<03:15, 86.15it/s, now=None]
#
#
# t:  90%|████████▉ | 145946/162768 [25:21<03:50, 73.02it/s, now=None]
#
#
# t:  90%|████████▉ | 145954/162768 [25:22<03:51, 72.67it/s, now=None]
#
#
# t:  90%|████████▉ | 145962/162768 [25:22<03:55, 71.50it/s, now=None]
#
#
# t:  90%|████████▉ | 145970/162768 [25:22<03:57, 70.79it/s, now=None]
#
#
# t:  90%|████████▉ | 145978/162768 [25:22<03:56, 71.04it/s, now=None]
#
#
# t:  90%|████████▉ | 145986/162768 [25:22<03:52, 72.25it/s, now=None]
#
#
# t:  90%|████████▉ | 145994/162768 [25:22<04:09, 67.11it/s, now=None]
#
#
# t:  90%|████████▉ | 146005/162768 [25:22<03:46, 73.98it/s, now=None]
#
#
# t:  90%|████████▉ | 146013/162768 [25:22<03:45, 74.37it/s, now=None]
#
#
# t:  90%|████████▉ | 146021/162768 [25:22<03:42, 75.26it/s, now=None]
#
#
# t:  90%|████████▉ | 146029/162768 [25:23<03:56, 70.73it/s, now=None]
#
#
# t:  90%|████████▉ | 146037/162768 [25:23<03:57, 70.33it/s, now=None]
#
#
# t:  90%|████████▉ | 146045/162768 [25:23<03:58, 69.98it/s, now=None]
#
#
# t:  90%|████████▉ | 146054/162768 [25:23<03:49, 72.92it/s, now=None]
#
#
# t:  90%|████████▉ | 146062/162768 [25:23<04:02, 68.95it/s, now=None]
#
#
# t:  90%|████████▉ | 146069/162768 [25:23<04:03, 68.64it/s, now=None]
#
#
# t:  90%|████████▉ | 146076/162768 [25:23<04:04, 68.31it/s, now=None]
#
#
# t:  90%|████████▉ | 146084/162768 [25:23<04:01, 69.10it/s, now=None]
#
#
# t:  90%|████████▉ | 146093/162768 [25:23<03:43, 74.55it/s, now=None]
#
#
# t:  90%|████████▉ | 146101/162768 [25:24<03:40, 75.64it/s, now=None]
#
#
# t:  90%|████████▉ | 146109/162768 [25:24<03:39, 76.05it/s, now=None]
#
#
# t:  90%|████████▉ | 146117/162768 [25:24<03:42, 74.68it/s, now=None]
#
#
# t:  90%|████████▉ | 146126/162768 [25:24<03:30, 78.92it/s, now=None]
#
#
# t:  90%|████████▉ | 146134/162768 [25:24<03:36, 76.79it/s, now=None]
#
#
# t:  90%|████████▉ | 146143/162768 [25:24<03:28, 79.83it/s, now=None]
#
#
# t:  90%|████████▉ | 146152/162768 [25:24<03:24, 81.31it/s, now=None]
#
#
# t:  90%|████████▉ | 146162/162768 [25:24<03:13, 85.84it/s, now=None]
#
#
# t:  90%|████████▉ | 146171/162768 [25:24<03:40, 75.34it/s, now=None]
#
#
# t:  90%|████████▉ | 146180/162768 [25:25<03:34, 77.34it/s, now=None]
#
#
# t:  90%|████████▉ | 146188/162768 [25:25<03:50, 71.97it/s, now=None]
#
#
# t:  90%|████████▉ | 146196/162768 [25:25<03:55, 70.27it/s, now=None]
#
#
# t:  90%|████████▉ | 146204/162768 [25:25<03:49, 72.19it/s, now=None]
#
#
# t:  90%|████████▉ | 146214/162768 [25:25<03:34, 77.11it/s, now=None]
#
#
# t:  90%|████████▉ | 146222/162768 [25:25<03:37, 76.10it/s, now=None]
#
#
# t:  90%|████████▉ | 146230/162768 [25:25<03:42, 74.17it/s, now=None]
#
#
# t:  90%|████████▉ | 146240/162768 [25:25<03:27, 79.66it/s, now=None]
#
#
# t:  90%|████████▉ | 146249/162768 [25:25<03:25, 80.35it/s, now=None]
#
#
# t:  90%|████████▉ | 146258/162768 [25:26<03:28, 79.24it/s, now=None]
#
#
# t:  90%|████████▉ | 146268/162768 [25:26<03:14, 84.64it/s, now=None]
#
#
# t:  90%|████████▉ | 146277/162768 [25:26<03:12, 85.57it/s, now=None]
#
#
# t:  90%|████████▉ | 146286/162768 [25:26<03:18, 82.92it/s, now=None]
#
#
# t:  90%|████████▉ | 146295/162768 [25:26<03:27, 79.57it/s, now=None]
#
#
# t:  90%|████████▉ | 146304/162768 [25:26<03:30, 78.10it/s, now=None]
#
#
# t:  90%|████████▉ | 146312/162768 [25:26<03:57, 69.31it/s, now=None]
#
#
# t:  90%|████████▉ | 146320/162768 [25:26<04:08, 66.25it/s, now=None]
#
#
# t:  90%|████████▉ | 146329/162768 [25:27<03:53, 70.49it/s, now=None]
#
#
# t:  90%|████████▉ | 146339/162768 [25:27<03:31, 77.67it/s, now=None]
#
#
# t:  90%|████████▉ | 146348/162768 [25:27<03:28, 78.92it/s, now=None]
#
#
# t:  90%|████████▉ | 146357/162768 [25:27<03:21, 81.47it/s, now=None]
#
#
# t:  90%|████████▉ | 146367/162768 [25:27<03:12, 85.40it/s, now=None]
#
#
# t:  90%|████████▉ | 146376/162768 [25:27<03:15, 84.02it/s, now=None]
#
#
# t:  90%|████████▉ | 146385/162768 [25:27<03:31, 77.35it/s, now=None]
#
#
# t:  90%|████████▉ | 146394/162768 [25:27<03:27, 78.98it/s, now=None]
#
#
# t:  90%|████████▉ | 146403/162768 [25:27<03:41, 73.78it/s, now=None]
#
#
# t:  90%|████████▉ | 146411/162768 [25:28<03:54, 69.65it/s, now=None]
#
#
# t:  90%|████████▉ | 146421/162768 [25:28<03:39, 74.64it/s, now=None]
#
#
# t:  90%|████████▉ | 146429/162768 [25:28<03:37, 75.00it/s, now=None]
#
#
# t:  90%|████████▉ | 146437/162768 [25:28<03:38, 74.65it/s, now=None]
#
#
# t:  90%|████████▉ | 146446/162768 [25:28<03:27, 78.68it/s, now=None]
#
#
# t:  90%|████████▉ | 146454/162768 [25:28<03:44, 72.68it/s, now=None]
#
#
# t:  90%|████████▉ | 146462/162768 [25:28<03:41, 73.57it/s, now=None]
#
#
# t:  90%|████████▉ | 146470/162768 [25:28<03:37, 74.95it/s, now=None]
#
#
# t:  90%|████████▉ | 146478/162768 [25:29<03:55, 69.09it/s, now=None]
#
#
# t:  90%|████████▉ | 146486/162768 [25:29<03:48, 71.11it/s, now=None]
#
#
# t:  90%|█████████ | 146494/162768 [25:29<04:06, 66.03it/s, now=None]
#
#
# t:  90%|█████████ | 146503/162768 [25:29<03:52, 70.10it/s, now=None]
#
#
# t:  90%|█████████ | 146511/162768 [25:29<04:08, 65.52it/s, now=None]
#
#
# t:  90%|█████████ | 146518/162768 [25:29<04:08, 65.36it/s, now=None]
#
#
# t:  90%|█████████ | 146528/162768 [25:29<03:39, 74.02it/s, now=None]
#
#
# t:  90%|█████████ | 146536/162768 [25:29<03:58, 68.13it/s, now=None]
#
#
# t:  90%|█████████ | 146544/162768 [25:29<03:59, 67.72it/s, now=None]
#
#
# t:  90%|█████████ | 146551/162768 [25:30<04:07, 65.47it/s, now=None]
#
#
# t:  90%|█████████ | 146558/162768 [25:30<04:11, 64.51it/s, now=None]
#
#
# t:  90%|█████████ | 146566/162768 [25:30<04:05, 65.90it/s, now=None]
#
#
# t:  90%|█████████ | 146575/162768 [25:30<03:50, 70.11it/s, now=None]
#
#
# t:  90%|█████████ | 146583/162768 [25:30<03:49, 70.50it/s, now=None]
#
#
# t:  90%|█████████ | 146591/162768 [25:30<03:43, 72.46it/s, now=None]
#
#
# t:  90%|█████████ | 146599/162768 [25:30<03:37, 74.39it/s, now=None]
#
#
# t:  90%|█████████ | 146609/162768 [25:30<03:24, 79.19it/s, now=None]
#
#
# t:  90%|█████████ | 146617/162768 [25:30<03:31, 76.19it/s, now=None]
#
#
# t:  90%|█████████ | 146625/162768 [25:31<03:39, 73.57it/s, now=None]
#
#
# t:  90%|█████████ | 146634/162768 [25:31<03:31, 76.28it/s, now=None]
#
#
# t:  90%|█████████ | 146642/162768 [25:31<03:33, 75.63it/s, now=None]
#
#
# t:  90%|█████████ | 146650/162768 [25:31<03:35, 74.63it/s, now=None]
#
#
# t:  90%|█████████ | 146658/162768 [25:31<03:40, 72.93it/s, now=None]
#
#
# t:  90%|█████████ | 146666/162768 [25:31<03:35, 74.59it/s, now=None]
#
#
# t:  90%|█████████ | 146675/162768 [25:31<03:32, 75.73it/s, now=None]
#
#
# t:  90%|█████████ | 146683/162768 [25:31<03:35, 74.81it/s, now=None]
#
#
# t:  90%|█████████ | 146692/162768 [25:31<03:23, 79.03it/s, now=None]
#
#
# t:  90%|█████████ | 146700/162768 [25:32<03:42, 72.30it/s, now=None]
#
#
# t:  90%|█████████ | 146710/162768 [25:32<03:49, 70.11it/s, now=None]
#
#
# t:  90%|█████████ | 146722/162768 [25:32<03:14, 82.46it/s, now=None]
#
#
# t:  90%|█████████ | 146732/162768 [25:32<03:04, 87.10it/s, now=None]
#
#
# t:  90%|█████████ | 146745/162768 [25:32<02:42, 98.85it/s, now=None]
#
#
# t:  90%|█████████ | 146757/162768 [25:32<02:36, 102.59it/s, now=None]
#
#
# t:  90%|█████████ | 146771/162768 [25:32<02:22, 112.35it/s, now=None]
#
#
# t:  90%|█████████ | 146783/162768 [25:32<02:21, 113.13it/s, now=None]
#
#
# t:  90%|█████████ | 146796/162768 [25:32<02:16, 116.63it/s, now=None]
#
#
# t:  90%|█████████ | 146809/162768 [25:33<02:14, 118.41it/s, now=None]
#
#
# t:  90%|█████████ | 146821/162768 [25:33<02:27, 108.24it/s, now=None]
#
#
# t:  90%|█████████ | 146835/162768 [25:33<02:19, 114.56it/s, now=None]
#
#
# t:  90%|█████████ | 146850/162768 [25:33<02:09, 123.14it/s, now=None]
#
#
# t:  90%|█████████ | 146863/162768 [25:33<02:12, 120.38it/s, now=None]
#
#
# t:  90%|█████████ | 146876/162768 [25:33<02:10, 121.37it/s, now=None]
#
#
# t:  90%|█████████ | 146889/162768 [25:33<02:12, 119.69it/s, now=None]
#
#
# t:  90%|█████████ | 146902/162768 [25:33<02:15, 116.76it/s, now=None]
#
#
# t:  90%|█████████ | 146914/162768 [25:33<02:17, 115.36it/s, now=None]
#
#
# t:  90%|█████████ | 146926/162768 [25:34<02:19, 113.78it/s, now=None]
#
#
# t:  90%|█████████ | 146938/162768 [25:34<02:24, 109.62it/s, now=None]
#
#
# t:  90%|█████████ | 146950/162768 [25:34<02:27, 107.13it/s, now=None]
#
#
# t:  90%|█████████ | 146963/162768 [25:34<02:20, 112.37it/s, now=None]
#
#
# t:  90%|█████████ | 146975/162768 [25:34<02:18, 114.09it/s, now=None]
#
#
# t:  90%|█████████ | 146987/162768 [25:34<02:18, 113.80it/s, now=None]
#
#
# t:  90%|█████████ | 146999/162768 [25:34<02:17, 114.36it/s, now=None]
#
#
# t:  90%|█████████ | 147011/162768 [25:34<02:19, 112.80it/s, now=None]
#
#
# t:  90%|█████████ | 147024/162768 [25:34<02:15, 116.56it/s, now=None]
#
#
# t:  90%|█████████ | 147037/162768 [25:35<02:13, 117.87it/s, now=None]
#
#
# t:  90%|█████████ | 147049/162768 [25:35<02:12, 118.37it/s, now=None]
#
#
# t:  90%|█████████ | 147062/162768 [25:35<02:12, 118.88it/s, now=None]
#
#
# t:  90%|█████████ | 147074/162768 [25:35<02:15, 115.88it/s, now=None]
#
#
# t:  90%|█████████ | 147088/162768 [25:35<02:08, 121.77it/s, now=None]
#
#
# t:  90%|█████████ | 147101/162768 [25:35<02:07, 122.68it/s, now=None]
#
#
# t:  90%|█████████ | 147114/162768 [25:35<02:11, 119.19it/s, now=None]
#
#
# t:  90%|█████████ | 147129/162768 [25:35<02:02, 127.44it/s, now=None]
#
#
# t:  90%|█████████ | 147142/162768 [25:35<02:12, 117.90it/s, now=None]
#
#
# t:  90%|█████████ | 147156/162768 [25:36<02:07, 122.76it/s, now=None]
#
#
# t:  90%|█████████ | 147170/162768 [25:36<02:02, 127.12it/s, now=None]
#
#
# t:  90%|█████████ | 147183/162768 [25:36<02:09, 120.35it/s, now=None]
#
#
# t:  90%|█████████ | 147196/162768 [25:36<02:07, 122.31it/s, now=None]
#
#
# t:  90%|█████████ | 147209/162768 [25:36<02:05, 123.89it/s, now=None]
#
#
# t:  90%|█████████ | 147222/162768 [25:36<02:07, 122.37it/s, now=None]
#
#
# t:  90%|█████████ | 147237/162768 [25:36<01:59, 129.65it/s, now=None]
#
#
# t:  90%|█████████ | 147251/162768 [25:36<02:07, 121.59it/s, now=None]
#
#
# t:  90%|█████████ | 147266/162768 [25:36<02:02, 126.74it/s, now=None]
#
#
# t:  90%|█████████ | 147279/162768 [25:37<02:02, 126.21it/s, now=None]
#
#
# t:  90%|█████████ | 147293/162768 [25:37<02:00, 128.48it/s, now=None]
#
#
# t:  91%|█████████ | 147306/162768 [25:37<02:04, 124.27it/s, now=None]
#
#
# t:  91%|█████████ | 147319/162768 [25:37<02:04, 124.29it/s, now=None]
#
#
# t:  91%|█████████ | 147332/162768 [25:37<02:06, 121.78it/s, now=None]
#
#
# t:  91%|█████████ | 147345/162768 [25:37<02:04, 123.87it/s, now=None]
#
#
# t:  91%|█████████ | 147359/162768 [25:37<02:00, 127.45it/s, now=None]
#
#
# t:  91%|█████████ | 147372/162768 [25:37<02:04, 124.01it/s, now=None]
#
#
# t:  91%|█████████ | 147386/162768 [25:37<02:00, 127.14it/s, now=None]
#
#
# t:  91%|█████████ | 147399/162768 [25:37<02:03, 124.75it/s, now=None]
#
#
# t:  91%|█████████ | 147414/162768 [25:38<01:57, 130.18it/s, now=None]
#
#
# t:  91%|█████████ | 147429/162768 [25:38<01:54, 133.80it/s, now=None]
#
#
# t:  91%|█████████ | 147443/162768 [25:38<02:02, 125.03it/s, now=None]
#
#
# t:  91%|█████████ | 147456/162768 [25:38<02:02, 124.79it/s, now=None]
#
#
# t:  91%|█████████ | 147469/162768 [25:38<02:03, 123.88it/s, now=None]
#
#
# t:  91%|█████████ | 147482/162768 [25:38<02:01, 125.53it/s, now=None]
#
#
# t:  91%|█████████ | 147496/162768 [25:38<01:57, 129.57it/s, now=None]
#
#
# t:  91%|█████████ | 147510/162768 [25:38<02:00, 126.45it/s, now=None]
#
#
# t:  91%|█████████ | 147525/162768 [25:38<01:56, 131.36it/s, now=None]
#
#
# t:  91%|█████████ | 147539/162768 [25:39<01:55, 132.36it/s, now=None]
#
#
# t:  91%|█████████ | 147553/162768 [25:39<01:56, 130.93it/s, now=None]
#
#
# t:  91%|█████████ | 147567/162768 [25:39<01:58, 128.68it/s, now=None]
#
#
# t:  91%|█████████ | 147580/162768 [25:39<02:02, 123.82it/s, now=None]
#
#
# t:  91%|█████████ | 147594/162768 [25:39<02:01, 125.24it/s, now=None]
#
#
# t:  91%|█████████ | 147608/162768 [25:39<01:58, 128.27it/s, now=None]
#
#
# t:  91%|█████████ | 147621/162768 [25:39<01:59, 126.80it/s, now=None]
#
#
# t:  91%|█████████ | 147634/162768 [25:39<02:00, 126.05it/s, now=None]
#
#
# t:  91%|█████████ | 147647/162768 [25:39<02:10, 115.52it/s, now=None]
#
#
# t:  91%|█████████ | 147659/162768 [25:40<02:09, 116.56it/s, now=None]
#
#
# t:  91%|█████████ | 147671/162768 [25:40<02:09, 116.80it/s, now=None]
#
#
# t:  91%|█████████ | 147683/162768 [25:40<02:11, 114.72it/s, now=None]
#
#
# t:  91%|█████████ | 147695/162768 [25:40<02:11, 114.99it/s, now=None]
#
#
# t:  91%|█████████ | 147707/162768 [25:40<02:14, 111.69it/s, now=None]
#
#
# t:  91%|█████████ | 147720/162768 [25:40<02:10, 115.30it/s, now=None]
#
#
# t:  91%|█████████ | 147732/162768 [25:40<02:10, 115.49it/s, now=None]
#
#
# t:  91%|█████████ | 147744/162768 [25:40<02:11, 114.32it/s, now=None]
#
#
# t:  91%|█████████ | 147757/162768 [25:40<02:06, 118.33it/s, now=None]
#
#
# t:  91%|█████████ | 147769/162768 [25:41<02:09, 116.09it/s, now=None]
#
#
# t:  91%|█████████ | 147781/162768 [25:41<02:13, 112.47it/s, now=None]
#
#
# t:  91%|█████████ | 147794/162768 [25:41<02:09, 115.95it/s, now=None]
#
#
# t:  91%|█████████ | 147806/162768 [25:41<02:11, 113.74it/s, now=None]
#
#
# t:  91%|█████████ | 147820/162768 [25:41<02:04, 120.19it/s, now=None]
#
#
# t:  91%|█████████ | 147833/162768 [25:41<02:07, 117.10it/s, now=None]
#
#
# t:  91%|█████████ | 147845/162768 [25:41<02:17, 108.87it/s, now=None]
#
#
# t:  91%|█████████ | 147859/162768 [25:41<02:07, 116.53it/s, now=None]
#
#
# t:  91%|█████████ | 147871/162768 [25:41<02:13, 111.86it/s, now=None]
#
#
# t:  91%|█████████ | 147886/162768 [25:42<02:02, 121.43it/s, now=None]
#
#
# t:  91%|█████████ | 147899/162768 [25:42<02:00, 123.74it/s, now=None]
#
#
# t:  91%|█████████ | 147912/162768 [25:42<02:04, 119.35it/s, now=None]
#
#
# t:  91%|█████████ | 147925/162768 [25:42<02:10, 113.80it/s, now=None]
#
#
# t:  91%|█████████ | 147937/162768 [25:42<02:20, 105.59it/s, now=None]
#
#
# t:  91%|█████████ | 147948/162768 [25:42<02:40, 92.12it/s, now=None]
#
#
# t:  91%|█████████ | 147958/162768 [25:42<02:52, 86.08it/s, now=None]
#
#
# t:  91%|█████████ | 147967/162768 [25:42<02:56, 83.85it/s, now=None]
#
#
# t:  91%|█████████ | 147976/162768 [25:43<02:55, 84.17it/s, now=None]
#
#
# t:  91%|█████████ | 147985/162768 [25:43<02:56, 83.97it/s, now=None]
#
#
# t:  91%|█████████ | 147994/162768 [25:43<02:55, 83.99it/s, now=None]
#
#
# t:  91%|█████████ | 148003/162768 [25:43<03:00, 82.02it/s, now=None]
#
#
# t:  91%|█████████ | 148012/162768 [25:43<03:11, 77.16it/s, now=None]
#
#
# t:  91%|█████████ | 148020/162768 [25:43<03:12, 76.43it/s, now=None]
#
#
# t:  91%|█████████ | 148028/162768 [25:43<03:21, 73.07it/s, now=None]
#
#
# t:  91%|█████████ | 148037/162768 [25:43<03:14, 75.87it/s, now=None]
#
#
# t:  91%|█████████ | 148047/162768 [25:43<03:03, 80.27it/s, now=None]
#
#
# t:  91%|█████████ | 148056/162768 [25:44<03:07, 78.28it/s, now=None]
#
#
# t:  91%|█████████ | 148066/162768 [25:44<03:07, 78.31it/s, now=None]
#
#
# t:  91%|█████████ | 148076/162768 [25:44<02:58, 82.38it/s, now=None]
#
#
# t:  91%|█████████ | 148086/162768 [25:44<02:51, 85.57it/s, now=None]
#
#
# t:  91%|█████████ | 148095/162768 [25:44<03:01, 81.02it/s, now=None]
#
#
# t:  91%|█████████ | 148104/162768 [25:44<02:58, 82.19it/s, now=None]
#
#
# t:  91%|█████████ | 148113/162768 [25:44<03:12, 76.12it/s, now=None]
#
#
# t:  91%|█████████ | 148121/162768 [25:44<03:15, 75.00it/s, now=None]
#
#
# t:  91%|█████████ | 148130/162768 [25:44<03:05, 78.72it/s, now=None]
#
#
# t:  91%|█████████ | 148138/162768 [25:45<03:09, 77.09it/s, now=None]
#
#
# t:  91%|█████████ | 148146/162768 [25:45<03:07, 77.87it/s, now=None]
#
#
# t:  91%|█████████ | 148155/162768 [25:45<03:05, 78.93it/s, now=None]
#
#
# t:  91%|█████████ | 148164/162768 [25:45<03:02, 79.87it/s, now=None]
#
#
# t:  91%|█████████ | 148174/162768 [25:45<02:53, 83.88it/s, now=None]
#
#
# t:  91%|█████████ | 148183/162768 [25:45<03:10, 76.53it/s, now=None]
#
#
# t:  91%|█████████ | 148193/162768 [25:45<02:58, 81.81it/s, now=None]
#
#
# t:  91%|█████████ | 148202/162768 [25:45<03:00, 80.80it/s, now=None]
#
#
# t:  91%|█████████ | 148211/162768 [25:45<02:57, 81.87it/s, now=None]
#
#
# t:  91%|█████████ | 148220/162768 [25:46<03:07, 77.75it/s, now=None]
#
#
# t:  91%|█████████ | 148228/162768 [25:46<03:18, 73.12it/s, now=None]
#
#
# t:  91%|█████████ | 148238/162768 [25:46<03:08, 77.14it/s, now=None]
#
#
# t:  91%|█████████ | 148246/162768 [25:46<03:11, 75.65it/s, now=None]
#
#
# t:  91%|█████████ | 148255/162768 [25:46<03:06, 77.86it/s, now=None]
#
#
# t:  91%|█████████ | 148264/162768 [25:46<03:07, 77.45it/s, now=None]
#
#
# t:  91%|█████████ | 148272/162768 [25:46<03:09, 76.37it/s, now=None]
#
#
# t:  91%|█████████ | 148280/162768 [25:46<03:23, 71.09it/s, now=None]
#
#
# t:  91%|█████████ | 148288/162768 [25:47<03:22, 71.45it/s, now=None]
#
#
# t:  91%|█████████ | 148297/162768 [25:47<03:18, 72.91it/s, now=None]
#
#
# t:  91%|█████████ | 148306/162768 [25:47<03:10, 75.92it/s, now=None]
#
#
# t:  91%|█████████ | 148314/162768 [25:47<03:11, 75.35it/s, now=None]
#
#
# t:  91%|█████████ | 148322/162768 [25:47<03:10, 75.73it/s, now=None]
#
#
# t:  91%|█████████ | 148332/162768 [25:47<02:59, 80.62it/s, now=None]
#
#
# t:  91%|█████████ | 148342/162768 [25:47<02:49, 85.13it/s, now=None]
#
#
# t:  91%|█████████ | 148351/162768 [25:47<02:52, 83.34it/s, now=None]
#
#
# t:  91%|█████████ | 148360/162768 [25:47<02:51, 83.90it/s, now=None]
#
#
# t:  91%|█████████ | 148369/162768 [25:48<02:58, 80.70it/s, now=None]
#
#
# t:  91%|█████████ | 148378/162768 [25:48<03:02, 78.90it/s, now=None]
#
#
# t:  91%|█████████ | 148386/162768 [25:48<03:02, 78.80it/s, now=None]
#
#
# t:  91%|█████████ | 148394/162768 [25:48<03:11, 74.87it/s, now=None]
#
#
# t:  91%|█████████ | 148404/162768 [25:48<03:00, 79.63it/s, now=None]
#
#
# t:  91%|█████████ | 148413/162768 [25:48<02:54, 82.23it/s, now=None]
#
#
# t:  91%|█████████ | 148422/162768 [25:48<02:57, 80.72it/s, now=None]
#
#
# t:  91%|█████████ | 148431/162768 [25:48<02:58, 80.46it/s, now=None]
#
#
# t:  91%|█████████ | 148440/162768 [25:48<03:05, 77.27it/s, now=None]
#
#
# t:  91%|█████████ | 148448/162768 [25:49<03:15, 73.15it/s, now=None]
#
#
# t:  91%|█████████ | 148456/162768 [25:49<03:29, 68.34it/s, now=None]
#
#
# t:  91%|█████████ | 148467/162768 [25:49<03:03, 77.77it/s, now=None]
#
#
# t:  91%|█████████ | 148478/162768 [25:49<02:49, 84.30it/s, now=None]
#
#
# t:  91%|█████████ | 148487/162768 [25:49<02:52, 82.78it/s, now=None]
#
#
# t:  91%|█████████ | 148496/162768 [25:49<02:58, 79.96it/s, now=None]
#
#
# t:  91%|█████████ | 148505/162768 [25:49<02:55, 81.23it/s, now=None]
#
#
# t:  91%|█████████ | 148514/162768 [25:49<02:58, 80.00it/s, now=None]
#
#
# t:  91%|█████████ | 148523/162768 [25:49<03:00, 78.92it/s, now=None]
#
#
# t:  91%|█████████▏| 148532/162768 [25:50<02:56, 80.80it/s, now=None]
#
#
# t:  91%|█████████▏| 148541/162768 [25:50<03:01, 78.55it/s, now=None]
#
#
# t:  91%|█████████▏| 148549/162768 [25:50<03:00, 78.56it/s, now=None]
#
#
# t:  91%|█████████▏| 148557/162768 [25:50<03:13, 73.50it/s, now=None]
#
#
# t:  91%|█████████▏| 148566/162768 [25:50<03:09, 74.90it/s, now=None]
#
#
# t:  91%|█████████▏| 148574/162768 [25:50<03:10, 74.41it/s, now=None]
#
#
# t:  91%|█████████▏| 148582/162768 [25:50<03:15, 72.44it/s, now=None]
#
#
# t:  91%|█████████▏| 148590/162768 [25:50<03:25, 69.14it/s, now=None]
#
#
# t:  91%|█████████▏| 148597/162768 [25:51<03:32, 66.64it/s, now=None]
#
#
# t:  91%|█████████▏| 148604/162768 [25:51<03:40, 64.14it/s, now=None]
#
#
# t:  91%|█████████▏| 148611/162768 [25:51<03:45, 62.80it/s, now=None]
#
#
# t:  91%|█████████▏| 148618/162768 [25:51<03:49, 61.62it/s, now=None]
#
#
# t:  91%|█████████▏| 148629/162768 [25:51<03:13, 73.12it/s, now=None]
#
#
# t:  91%|█████████▏| 148638/162768 [25:51<03:11, 73.75it/s, now=None]
#
#
# t:  91%|█████████▏| 148646/162768 [25:51<03:17, 71.62it/s, now=None]
#
#
# t:  91%|█████████▏| 148654/162768 [25:51<03:24, 69.14it/s, now=None]
#
#
# t:  91%|█████████▏| 148661/162768 [25:51<03:23, 69.34it/s, now=None]
#
#
# t:  91%|█████████▏| 148670/162768 [25:52<03:12, 73.10it/s, now=None]
#
#
# t:  91%|█████████▏| 148679/162768 [25:52<03:02, 77.12it/s, now=None]
#
#
# t:  91%|█████████▏| 148687/162768 [25:52<03:09, 74.23it/s, now=None]
#
#
# t:  91%|█████████▏| 148695/162768 [25:52<03:12, 72.97it/s, now=None]
#
#
# t:  91%|█████████▏| 148704/162768 [25:52<03:07, 74.92it/s, now=None]
#
#
# t:  91%|█████████▏| 148712/162768 [25:52<03:05, 75.66it/s, now=None]
#
#
# t:  91%|█████████▏| 148723/162768 [25:52<02:45, 84.66it/s, now=None]
#
#
# t:  91%|█████████▏| 148732/162768 [25:52<03:02, 76.94it/s, now=None]
#
#
# t:  91%|█████████▏| 148741/162768 [25:52<02:54, 80.23it/s, now=None]
#
#
# t:  91%|█████████▏| 148750/162768 [25:53<03:02, 76.76it/s, now=None]
#
#
# t:  91%|█████████▏| 148759/162768 [25:53<03:06, 75.23it/s, now=None]
#
#
# t:  91%|█████████▏| 148768/162768 [25:53<02:57, 78.80it/s, now=None]
#
#
# t:  91%|█████████▏| 148776/162768 [25:53<03:05, 75.56it/s, now=None]
#
#
# t:  91%|█████████▏| 148784/162768 [25:53<03:07, 74.65it/s, now=None]
#
#
# t:  91%|█████████▏| 148793/162768 [25:53<02:58, 78.09it/s, now=None]
#
#
# t:  91%|█████████▏| 148801/162768 [25:53<02:57, 78.49it/s, now=None]
#
#
# t:  91%|█████████▏| 148812/162768 [25:53<02:43, 85.55it/s, now=None]
#
#
# t:  91%|█████████▏| 148823/162768 [25:53<02:31, 91.95it/s, now=None]
#
#
# t:  91%|█████████▏| 148834/162768 [25:54<02:24, 96.35it/s, now=None]
#
#
# t:  91%|█████████▏| 148844/162768 [25:54<02:25, 95.54it/s, now=None]
#
#
# t:  91%|█████████▏| 148859/162768 [25:54<02:06, 110.04it/s, now=None]
#
#
# t:  91%|█████████▏| 148871/162768 [25:54<02:08, 108.16it/s, now=None]
#
#
# t:  91%|█████████▏| 148882/162768 [25:54<02:11, 105.39it/s, now=None]
#
#
# t:  91%|█████████▏| 148893/162768 [25:54<02:10, 106.25it/s, now=None]
#
#
# t:  91%|█████████▏| 148904/162768 [25:54<02:11, 105.28it/s, now=None]
#
#
# t:  91%|█████████▏| 148915/162768 [25:54<02:15, 102.52it/s, now=None]
#
#
# t:  91%|█████████▏| 148926/162768 [25:54<02:25, 95.20it/s, now=None]
#
#
# t:  92%|█████████▏| 148938/162768 [25:55<02:16, 101.20it/s, now=None]
#
#
# t:  92%|█████████▏| 148949/162768 [25:55<02:15, 101.74it/s, now=None]
#
#
# t:  92%|█████████▏| 148961/162768 [25:55<02:09, 106.28it/s, now=None]
#
#
# t:  92%|█████████▏| 148972/162768 [25:55<02:10, 105.91it/s, now=None]
#
#
# t:  92%|█████████▏| 148984/162768 [25:55<02:07, 108.01it/s, now=None]
#
#
# t:  92%|█████████▏| 148995/162768 [25:55<02:13, 103.16it/s, now=None]
#
#
# t:  92%|█████████▏| 149007/162768 [25:55<02:08, 107.03it/s, now=None]
#
#
# t:  92%|█████████▏| 149020/162768 [25:55<02:01, 113.36it/s, now=None]
#
#
# t:  92%|█████████▏| 149032/162768 [25:55<02:03, 110.86it/s, now=None]
#
#
# t:  92%|█████████▏| 149044/162768 [25:56<02:01, 113.06it/s, now=None]
#
#
# t:  92%|█████████▏| 149057/162768 [25:56<01:56, 117.22it/s, now=None]
#
#
# t:  92%|█████████▏| 149070/162768 [25:56<01:53, 120.83it/s, now=None]
#
#
# t:  92%|█████████▏| 149083/162768 [25:56<01:55, 118.92it/s, now=None]
#
#
# t:  92%|█████████▏| 149096/162768 [25:56<01:55, 118.61it/s, now=None]
#
#
# t:  92%|█████████▏| 149110/162768 [25:56<01:51, 122.37it/s, now=None]
#
#
# t:  92%|█████████▏| 149124/162768 [25:56<01:50, 123.47it/s, now=None]
#
#
# t:  92%|█████████▏| 149137/162768 [25:56<01:51, 122.72it/s, now=None]
#
#
# t:  92%|█████████▏| 149151/162768 [25:56<01:47, 126.94it/s, now=None]
#
#
# t:  92%|█████████▏| 149164/162768 [25:56<01:47, 126.63it/s, now=None]
#
#
# t:  92%|█████████▏| 149177/162768 [25:57<01:55, 117.42it/s, now=None]
#
#
# t:  92%|█████████▏| 149189/162768 [25:57<01:58, 114.18it/s, now=None]
#
#
# t:  92%|█████████▏| 149202/162768 [25:57<01:55, 117.74it/s, now=None]
#
#
# t:  92%|█████████▏| 149214/162768 [25:57<01:57, 115.50it/s, now=None]
#
#
# t:  92%|█████████▏| 149226/162768 [25:57<02:03, 109.33it/s, now=None]
#
#
# t:  92%|█████████▏| 149238/162768 [25:57<02:09, 104.58it/s, now=None]
#
#
# t:  92%|█████████▏| 149251/162768 [25:57<02:02, 110.30it/s, now=None]
#
#
# t:  92%|█████████▏| 149263/162768 [25:57<02:08, 105.30it/s, now=None]
#
#
# t:  92%|█████████▏| 149274/162768 [25:58<02:07, 106.12it/s, now=None]
#
#
# t:  92%|█████████▏| 149288/162768 [25:58<01:57, 114.97it/s, now=None]
#
#
# t:  92%|█████████▏| 149300/162768 [25:58<01:57, 115.00it/s, now=None]
#
#
# t:  92%|█████████▏| 149315/162768 [25:58<01:49, 123.34it/s, now=None]
#
#
# t:  92%|█████████▏| 149328/162768 [25:58<01:47, 124.88it/s, now=None]
#
#
# t:  92%|█████████▏| 149341/162768 [25:58<01:49, 123.08it/s, now=None]
#
#
# t:  92%|█████████▏| 149354/162768 [25:58<01:50, 121.67it/s, now=None]
#
#
# t:  92%|█████████▏| 149367/162768 [25:58<01:53, 118.48it/s, now=None]
#
#
# t:  92%|█████████▏| 149381/162768 [25:58<01:47, 124.17it/s, now=None]
#
#
# t:  92%|█████████▏| 149394/162768 [25:58<01:48, 122.89it/s, now=None]
#
#
# t:  92%|█████████▏| 149407/162768 [25:59<01:47, 123.85it/s, now=None]
#
#
# t:  92%|█████████▏| 149420/162768 [25:59<01:51, 119.46it/s, now=None]
#
#
# t:  92%|█████████▏| 149434/162768 [25:59<01:48, 123.11it/s, now=None]
#
#
# t:  92%|█████████▏| 149447/162768 [25:59<01:47, 124.40it/s, now=None]
#
#
# t:  92%|█████████▏| 149460/162768 [25:59<01:49, 121.40it/s, now=None]
#
#
# t:  92%|█████████▏| 149473/162768 [25:59<01:51, 119.53it/s, now=None]
#
#
# t:  92%|█████████▏| 149486/162768 [25:59<01:49, 121.11it/s, now=None]
#
#
# t:  92%|█████████▏| 149499/162768 [25:59<01:53, 116.68it/s, now=None]
#
#
# t:  92%|█████████▏| 149512/162768 [25:59<01:50, 120.27it/s, now=None]
#
#
# t:  92%|█████████▏| 149525/162768 [26:00<01:50, 119.66it/s, now=None]
#
#
# t:  92%|█████████▏| 149538/162768 [26:00<01:51, 118.70it/s, now=None]
#
#
# t:  92%|█████████▏| 149550/162768 [26:00<01:51, 118.44it/s, now=None]
#
#
# t:  92%|█████████▏| 149562/162768 [26:00<01:51, 118.81it/s, now=None]
#
#
# t:  92%|█████████▏| 149574/162768 [26:00<01:57, 112.65it/s, now=None]
#
#
# t:  92%|█████████▏| 149587/162768 [26:00<01:52, 117.03it/s, now=None]
#
#
# t:  92%|█████████▏| 149599/162768 [26:00<02:02, 107.55it/s, now=None]
#
#
# t:  92%|█████████▏| 149612/162768 [26:00<01:55, 113.61it/s, now=None]
#
#
# t:  92%|█████████▏| 149624/162768 [26:00<02:01, 107.83it/s, now=None]
#
#
# t:  92%|█████████▏| 149636/162768 [26:01<01:59, 109.53it/s, now=None]
#
#
# t:  92%|█████████▏| 149648/162768 [26:01<01:58, 110.71it/s, now=None]
#
#
# t:  92%|█████████▏| 149661/162768 [26:01<01:54, 114.17it/s, now=None]
#
#
# t:  92%|█████████▏| 149675/162768 [26:01<01:48, 120.76it/s, now=None]
#
#
# t:  92%|█████████▏| 149688/162768 [26:01<01:51, 117.83it/s, now=None]
#
#
# t:  92%|█████████▏| 149702/162768 [26:01<01:45, 123.36it/s, now=None]
#
#
# t:  92%|█████████▏| 149716/162768 [26:01<01:46, 122.81it/s, now=None]
#
#
# t:  92%|█████████▏| 149729/162768 [26:01<01:48, 120.63it/s, now=None]
#
#
# t:  92%|█████████▏| 149743/162768 [26:01<01:44, 125.19it/s, now=None]
#
#
# t:  92%|█████████▏| 149756/162768 [26:02<01:45, 122.84it/s, now=None]
#
#
# t:  92%|█████████▏| 149770/162768 [26:02<01:42, 127.02it/s, now=None]
#
#
# t:  92%|█████████▏| 149783/162768 [26:02<01:43, 125.68it/s, now=None]
#
#
# t:  92%|█████████▏| 149796/162768 [26:02<01:42, 126.45it/s, now=None]
#
#
# t:  92%|█████████▏| 149809/162768 [26:02<01:49, 118.71it/s, now=None]
#
#
# t:  92%|█████████▏| 149824/162768 [26:02<01:42, 126.09it/s, now=None]
#
#
# t:  92%|█████████▏| 149838/162768 [26:02<01:39, 129.81it/s, now=None]
#
#
# t:  92%|█████████▏| 149852/162768 [26:02<01:47, 120.37it/s, now=None]
#
#
# t:  92%|█████████▏| 149865/162768 [26:02<01:48, 119.01it/s, now=None]
#
#
# t:  92%|█████████▏| 149880/162768 [26:03<01:41, 126.51it/s, now=None]
#
#
# t:  92%|█████████▏| 149893/162768 [26:03<01:41, 126.98it/s, now=None]
#
#
# t:  92%|█████████▏| 149906/162768 [26:03<01:46, 120.86it/s, now=None]
#
#
# t:  92%|█████████▏| 149921/162768 [26:03<01:41, 126.30it/s, now=None]
#
#
# t:  92%|█████████▏| 149934/162768 [26:03<01:42, 125.69it/s, now=None]
#
#
# t:  92%|█████████▏| 149947/162768 [26:03<01:44, 122.14it/s, now=None]
#
#
# t:  92%|█████████▏| 149960/162768 [26:03<01:43, 123.44it/s, now=None]
#
#
# t:  92%|█████████▏| 149973/162768 [26:03<01:59, 107.43it/s, now=None]
#
#
# t:  92%|█████████▏| 149985/162768 [26:03<02:05, 101.65it/s, now=None]
#
#
# t:  92%|█████████▏| 149996/162768 [26:04<02:12, 96.59it/s, now=None]
#
#
# t:  92%|█████████▏| 150007/162768 [26:04<02:08, 99.22it/s, now=None]
#
#
# t:  92%|█████████▏| 150018/162768 [26:04<02:15, 94.00it/s, now=None]
#
#
# t:  92%|█████████▏| 150028/162768 [26:04<02:19, 91.31it/s, now=None]
#
#
# t:  92%|█████████▏| 150038/162768 [26:04<02:18, 91.96it/s, now=None]
#
#
# t:  92%|█████████▏| 150048/162768 [26:04<02:20, 90.77it/s, now=None]
#
#
# t:  92%|█████████▏| 150058/162768 [26:04<02:16, 93.19it/s, now=None]
#
#
# t:  92%|█████████▏| 150068/162768 [26:04<02:18, 91.54it/s, now=None]
#
#
# t:  92%|█████████▏| 150079/162768 [26:04<02:11, 96.31it/s, now=None]
#
#
# t:  92%|█████████▏| 150089/162768 [26:05<02:17, 91.93it/s, now=None]
#
#
# t:  92%|█████████▏| 150100/162768 [26:05<02:11, 96.22it/s, now=None]
#
#
# t:  92%|█████████▏| 150110/162768 [26:05<02:12, 95.62it/s, now=None]
#
#
# t:  92%|█████████▏| 150120/162768 [26:05<02:15, 93.05it/s, now=None]
#
#
# t:  92%|█████████▏| 150130/162768 [26:05<02:25, 86.92it/s, now=None]
#
#
# t:  92%|█████████▏| 150139/162768 [26:05<02:28, 85.19it/s, now=None]
#
#
# t:  92%|█████████▏| 150148/162768 [26:05<02:35, 81.38it/s, now=None]
#
#
# t:  92%|█████████▏| 150157/162768 [26:05<02:37, 80.00it/s, now=None]
#
#
# t:  92%|█████████▏| 150166/162768 [26:06<02:50, 74.09it/s, now=None]
#
#
# t:  92%|█████████▏| 150174/162768 [26:06<02:48, 74.62it/s, now=None]
#
#
# t:  92%|█████████▏| 150183/162768 [26:06<02:41, 78.13it/s, now=None]
#
#
# t:  92%|█████████▏| 150192/162768 [26:06<02:35, 81.01it/s, now=None]
#
#
# t:  92%|█████████▏| 150201/162768 [26:06<02:32, 82.16it/s, now=None]
#
#
# t:  92%|█████████▏| 150210/162768 [26:06<02:33, 81.94it/s, now=None]
#
#
# t:  92%|█████████▏| 150220/162768 [26:06<02:25, 86.04it/s, now=None]
#
#
# t:  92%|█████████▏| 150229/162768 [26:06<02:25, 86.37it/s, now=None]
#
#
# t:  92%|█████████▏| 150238/162768 [26:06<02:26, 85.81it/s, now=None]
#
#
# t:  92%|█████████▏| 150247/162768 [26:07<02:32, 82.02it/s, now=None]
#
#
# t:  92%|█████████▏| 150256/162768 [26:07<02:42, 76.82it/s, now=None]
#
#
# t:  92%|█████████▏| 150264/162768 [26:07<02:57, 70.50it/s, now=None]
#
#
# t:  92%|█████████▏| 150273/162768 [26:07<02:52, 72.52it/s, now=None]
#
#
# t:  92%|█████████▏| 150282/162768 [26:07<02:44, 75.79it/s, now=None]
#
#
# t:  92%|█████████▏| 150291/162768 [26:07<02:42, 77.01it/s, now=None]
#
#
# t:  92%|█████████▏| 150301/162768 [26:07<02:32, 81.69it/s, now=None]
#
#
# t:  92%|█████████▏| 150310/162768 [26:07<02:43, 76.13it/s, now=None]
#
#
# t:  92%|█████████▏| 150320/162768 [26:07<02:33, 81.03it/s, now=None]
#
#
# t:  92%|█████████▏| 150329/162768 [26:08<02:29, 83.38it/s, now=None]
#
#
# t:  92%|█████████▏| 150338/162768 [26:08<02:26, 84.95it/s, now=None]
#
#
# t:  92%|█████████▏| 150347/162768 [26:08<02:28, 83.50it/s, now=None]
#
#
# t:  92%|█████████▏| 150356/162768 [26:08<02:43, 75.82it/s, now=None]
#
#
# t:  92%|█████████▏| 150365/162768 [26:08<02:36, 79.06it/s, now=None]
#
#
# t:  92%|█████████▏| 150374/162768 [26:08<02:35, 79.45it/s, now=None]
#
#
# t:  92%|█████████▏| 150384/162768 [26:08<02:26, 84.69it/s, now=None]
#
#
# t:  92%|█████████▏| 150393/162768 [26:08<02:26, 84.70it/s, now=None]
#
#
# t:  92%|█████████▏| 150402/162768 [26:08<02:32, 80.97it/s, now=None]
#
#
# t:  92%|█████████▏| 150411/162768 [26:09<02:33, 80.46it/s, now=None]
#
#
# t:  92%|█████████▏| 150420/162768 [26:09<02:36, 78.89it/s, now=None]
#
#
# t:  92%|█████████▏| 150428/162768 [26:09<02:35, 79.14it/s, now=None]
#
#
# t:  92%|█████████▏| 150436/162768 [26:09<02:43, 75.61it/s, now=None]
#
#
# t:  92%|█████████▏| 150445/162768 [26:09<02:41, 76.44it/s, now=None]
#
#
# t:  92%|█████████▏| 150453/162768 [26:09<02:44, 74.84it/s, now=None]
#
#
# t:  92%|█████████▏| 150461/162768 [26:09<02:41, 76.02it/s, now=None]
#
#
# t:  92%|█████████▏| 150469/162768 [26:09<02:43, 75.41it/s, now=None]
#
#
# t:  92%|█████████▏| 150478/162768 [26:09<02:38, 77.63it/s, now=None]
#
#
# t:  92%|█████████▏| 150486/162768 [26:10<02:43, 75.26it/s, now=None]
#
#
# t:  92%|█████████▏| 150496/162768 [26:10<02:41, 75.76it/s, now=None]
#
#
# t:  92%|█████████▏| 150504/162768 [26:10<02:51, 71.62it/s, now=None]
#
#
# t:  92%|█████████▏| 150512/162768 [26:10<02:53, 70.76it/s, now=None]
#
#
# t:  92%|█████████▏| 150520/162768 [26:10<02:48, 72.58it/s, now=None]
#
#
# t:  92%|█████████▏| 150531/162768 [26:10<02:29, 81.91it/s, now=None]
#
#
# t:  92%|█████████▏| 150540/162768 [26:10<02:26, 83.22it/s, now=None]
#
#
# t:  92%|█████████▏| 150549/162768 [26:10<02:24, 84.48it/s, now=None]
#
#
# t:  92%|█████████▏| 150558/162768 [26:10<02:23, 84.94it/s, now=None]
#
#
# t:  93%|█████████▎| 150568/162768 [26:11<02:19, 87.19it/s, now=None]
#
#
# t:  93%|█████████▎| 150577/162768 [26:11<02:23, 85.05it/s, now=None]
#
#
# t:  93%|█████████▎| 150586/162768 [26:11<02:32, 79.91it/s, now=None]
#
#
# t:  93%|█████████▎| 150595/162768 [26:11<02:33, 79.28it/s, now=None]
#
#
# t:  93%|█████████▎| 150605/162768 [26:11<02:25, 83.74it/s, now=None]
#
#
# t:  93%|█████████▎| 150614/162768 [26:11<02:23, 84.99it/s, now=None]
#
#
# t:  93%|█████████▎| 150624/162768 [26:11<02:16, 89.08it/s, now=None]
#
#
# t:  93%|█████████▎| 150633/162768 [26:11<02:17, 88.05it/s, now=None]
#
#
# t:  93%|█████████▎| 150642/162768 [26:11<02:20, 86.52it/s, now=None]
#
#
# t:  93%|█████████▎| 150651/162768 [26:12<02:19, 86.90it/s, now=None]
#
#
# t:  93%|█████████▎| 150660/162768 [26:12<02:17, 87.79it/s, now=None]
#
#
# t:  93%|█████████▎| 150670/162768 [26:12<02:14, 90.10it/s, now=None]
#
#
# t:  93%|█████████▎| 150680/162768 [26:12<02:14, 89.57it/s, now=None]
#
#
# t:  93%|█████████▎| 150690/162768 [26:12<02:14, 89.50it/s, now=None]
#
#
# t:  93%|█████████▎| 150700/162768 [26:12<02:13, 90.60it/s, now=None]
#
#
# t:  93%|█████████▎| 150711/162768 [26:12<02:08, 93.75it/s, now=None]
#
#
# t:  93%|█████████▎| 150721/162768 [26:12<02:09, 92.76it/s, now=None]
#
#
# t:  93%|█████████▎| 150731/162768 [26:12<02:11, 91.50it/s, now=None]
#
#
# t:  93%|█████████▎| 150741/162768 [26:13<02:13, 90.14it/s, now=None]
#
#
# t:  93%|█████████▎| 150751/162768 [26:13<02:12, 90.91it/s, now=None]
#
#
# t:  93%|█████████▎| 150761/162768 [26:13<02:19, 86.31it/s, now=None]
#
#
# t:  93%|█████████▎| 150770/162768 [26:13<02:27, 81.55it/s, now=None]
#
#
# t:  93%|█████████▎| 150779/162768 [26:13<02:33, 78.33it/s, now=None]
#
#
# t:  93%|█████████▎| 150788/162768 [26:13<02:29, 80.20it/s, now=None]
#
#
# t:  93%|█████████▎| 150797/162768 [26:13<02:25, 82.14it/s, now=None]
#
#
# t:  93%|█████████▎| 150806/162768 [26:13<02:26, 81.59it/s, now=None]
#
#
# t:  93%|█████████▎| 150815/162768 [26:13<02:23, 83.07it/s, now=None]
#
#
# t:  93%|█████████▎| 150824/162768 [26:14<02:24, 82.66it/s, now=None]
#
#
# t:  93%|█████████▎| 150833/162768 [26:14<02:40, 74.18it/s, now=None]
#
#
# t:  93%|█████████▎| 150841/162768 [26:14<02:47, 71.30it/s, now=None]
#
#
# t:  93%|█████████▎| 150849/162768 [26:14<03:03, 64.86it/s, now=None]
#
#
# t:  93%|█████████▎| 150857/162768 [26:14<02:53, 68.46it/s, now=None]
#
#
# t:  93%|█████████▎| 150867/162768 [26:14<02:38, 74.99it/s, now=None]
#
#
# t:  93%|█████████▎| 150875/162768 [26:14<02:39, 74.73it/s, now=None]
#
#
# t:  93%|█████████▎| 150884/162768 [26:14<02:30, 78.71it/s, now=None]
#
#
# t:  93%|█████████▎| 150893/162768 [26:15<02:30, 79.06it/s, now=None]
#
#
# t:  93%|█████████▎| 150902/162768 [26:15<02:27, 80.65it/s, now=None]
#
#
# t:  93%|█████████▎| 150911/162768 [26:15<02:28, 80.10it/s, now=None]
#
#
# t:  93%|█████████▎| 150920/162768 [26:15<02:36, 75.72it/s, now=None]
#
#
# t:  93%|█████████▎| 150928/162768 [26:15<02:38, 74.89it/s, now=None]
#
#
# t:  93%|█████████▎| 150936/162768 [26:15<02:37, 75.05it/s, now=None]
#
#
# t:  93%|█████████▎| 150945/162768 [26:15<02:33, 77.26it/s, now=None]
#
#
# t:  93%|█████████▎| 150955/162768 [26:15<02:22, 82.79it/s, now=None]
#
#
# t:  93%|█████████▎| 150966/162768 [26:15<02:12, 89.08it/s, now=None]
#
#
# t:  93%|█████████▎| 150980/162768 [26:16<01:54, 102.67it/s, now=None]
#
#
# t:  93%|█████████▎| 150991/162768 [26:16<01:54, 103.12it/s, now=None]
#
#
# t:  93%|█████████▎| 151005/162768 [26:16<01:44, 112.70it/s, now=None]
#
#
# t:  93%|█████████▎| 151021/162768 [26:16<01:34, 124.05it/s, now=None]
#
#
# t:  93%|█████████▎| 151034/162768 [26:16<01:37, 120.72it/s, now=None]
#
#
# t:  93%|█████████▎| 151049/162768 [26:16<01:31, 128.52it/s, now=None]
#
#
# t:  93%|█████████▎| 151062/162768 [26:16<01:33, 125.10it/s, now=None]
#
#
# t:  93%|█████████▎| 151075/162768 [26:16<01:38, 119.04it/s, now=None]
#
#
# t:  93%|█████████▎| 151087/162768 [26:16<01:39, 117.06it/s, now=None]
#
#
# t:  93%|█████████▎| 151099/162768 [26:17<01:42, 113.36it/s, now=None]
#
#
# t:  93%|█████████▎| 151113/162768 [26:17<01:36, 120.31it/s, now=None]
#
#
# t:  93%|█████████▎| 151126/162768 [26:17<01:40, 115.34it/s, now=None]
#
#
# t:  93%|█████████▎| 151140/162768 [26:17<01:36, 121.11it/s, now=None]
#
#
# t:  93%|█████████▎| 151153/162768 [26:17<01:35, 121.37it/s, now=None]
#
#
# t:  93%|█████████▎| 151168/162768 [26:17<01:30, 127.89it/s, now=None]
#
#
# t:  93%|█████████▎| 151181/162768 [26:17<01:32, 124.67it/s, now=None]
#
#
# t:  93%|█████████▎| 151194/162768 [26:17<01:35, 120.90it/s, now=None]
#
#
# t:  93%|█████████▎| 151207/162768 [26:17<01:36, 119.71it/s, now=None]
#
#
# t:  93%|█████████▎| 151220/162768 [26:18<01:42, 112.15it/s, now=None]
#
#
# t:  93%|█████████▎| 151233/162768 [26:18<01:41, 113.42it/s, now=None]
#
#
# t:  93%|█████████▎| 151246/162768 [26:18<01:38, 116.42it/s, now=None]
#
#
# t:  93%|█████████▎| 151258/162768 [26:18<01:41, 113.59it/s, now=None]
#
#
# t:  93%|█████████▎| 151270/162768 [26:18<01:41, 113.12it/s, now=None]
#
#
# t:  93%|█████████▎| 151282/162768 [26:18<01:45, 109.29it/s, now=None]
#
#
# t:  93%|█████████▎| 151294/162768 [26:18<01:44, 110.03it/s, now=None]
#
#
# t:  93%|█████████▎| 151306/162768 [26:18<01:46, 108.09it/s, now=None]
#
#
# t:  93%|█████████▎| 151317/162768 [26:18<01:51, 102.45it/s, now=None]
#
#
# t:  93%|█████████▎| 151331/162768 [26:19<01:42, 111.72it/s, now=None]
#
#
# t:  93%|█████████▎| 151343/162768 [26:19<01:46, 107.69it/s, now=None]
#
#
# t:  93%|█████████▎| 151354/162768 [26:19<01:50, 103.14it/s, now=None]
#
#
# t:  93%|█████████▎| 151366/162768 [26:19<01:46, 107.42it/s, now=None]
#
#
# t:  93%|█████████▎| 151377/162768 [26:19<01:50, 102.90it/s, now=None]
#
#
# t:  93%|█████████▎| 151390/162768 [26:19<01:43, 109.93it/s, now=None]
#
#
# t:  93%|█████████▎| 151402/162768 [26:19<01:43, 109.51it/s, now=None]
#
#
# t:  93%|█████████▎| 151415/162768 [26:19<01:40, 113.07it/s, now=None]
#
#
# t:  93%|█████████▎| 151427/162768 [26:19<01:43, 109.34it/s, now=None]
#
#
# t:  93%|█████████▎| 151439/162768 [26:20<01:45, 107.17it/s, now=None]
#
#
# t:  93%|█████████▎| 151452/162768 [26:20<01:40, 112.41it/s, now=None]
#
#
# t:  93%|█████████▎| 151464/162768 [26:20<01:41, 111.27it/s, now=None]
#
#
# t:  93%|█████████▎| 151476/162768 [26:20<01:40, 112.85it/s, now=None]
#
#
# t:  93%|█████████▎| 151490/162768 [26:20<01:35, 118.40it/s, now=None]
#
#
# t:  93%|█████████▎| 151502/162768 [26:20<01:39, 112.98it/s, now=None]
#
#
# t:  93%|█████████▎| 151514/162768 [26:20<01:39, 113.67it/s, now=None]
#
#
# t:  93%|█████████▎| 151526/162768 [26:20<01:40, 111.79it/s, now=None]
#
#
# t:  93%|█████████▎| 151538/162768 [26:20<01:41, 110.54it/s, now=None]
#
#
# t:  93%|█████████▎| 151552/162768 [26:21<01:35, 117.00it/s, now=None]
#
#
# t:  93%|█████████▎| 151564/162768 [26:21<01:37, 114.81it/s, now=None]
#
#
# t:  93%|█████████▎| 151580/162768 [26:21<01:29, 125.14it/s, now=None]
#
#
# t:  93%|█████████▎| 151593/162768 [26:21<01:32, 120.46it/s, now=None]
#
#
# t:  93%|█████████▎| 151607/162768 [26:21<01:28, 125.84it/s, now=None]
#
#
# t:  93%|█████████▎| 151621/162768 [26:21<01:26, 128.18it/s, now=None]
#
#
# t:  93%|█████████▎| 151634/162768 [26:21<01:30, 123.18it/s, now=None]
#
#
# t:  93%|█████████▎| 151648/162768 [26:21<01:27, 126.90it/s, now=None]
#
#
# t:  93%|█████████▎| 151661/162768 [26:21<01:32, 120.12it/s, now=None]
#
#
# t:  93%|█████████▎| 151674/162768 [26:22<01:36, 114.37it/s, now=None]
#
#
# t:  93%|█████████▎| 151686/162768 [26:22<01:36, 115.29it/s, now=None]
#
#
# t:  93%|█████████▎| 151698/162768 [26:22<01:38, 112.22it/s, now=None]
#
#
# t:  93%|█████████▎| 151710/162768 [26:22<01:37, 113.49it/s, now=None]
#
#
# t:  93%|█████████▎| 151722/162768 [26:22<01:37, 113.67it/s, now=None]
#
#
# t:  93%|█████████▎| 151734/162768 [26:22<01:42, 107.62it/s, now=None]
#
#
# ...
#
#
# t:  99%|█████████▊| 160329/162768 [27:50<00:18, 130.19it/s, now=None]
#
#
# t:  99%|█████████▊| 160343/162768 [27:50<00:19, 125.61it/s, now=None]
#
#
# t:  99%|█████████▊| 160357/162768 [27:50<00:18, 128.00it/s, now=None]
#
#
# t:  99%|█████████▊| 160372/162768 [27:51<00:18, 132.28it/s, now=None]
#
#
# t:  99%|█████████▊| 160386/162768 [27:51<00:19, 124.01it/s, now=None]
#
#
# t:  99%|█████████▊| 160399/162768 [27:51<00:20, 116.92it/s, now=None]
#
#
# t:  99%|█████████▊| 160411/162768 [27:51<00:20, 114.78it/s, now=None]
#
#
# t:  99%|█████████▊| 160425/162768 [27:51<00:19, 119.33it/s, now=None]
#
#
# t:  99%|█████████▊| 160438/162768 [27:51<00:20, 115.31it/s, now=None]
#
#
# t:  99%|█████████▊| 160450/162768 [27:51<00:19, 116.49it/s, now=None]
#
#
# t:  99%|█████████▊| 160465/162768 [27:51<00:18, 121.93it/s, now=None]
#
#
# t:  99%|█████████▊| 160478/162768 [27:51<00:19, 118.30it/s, now=None]
#
#
# t:  99%|█████████▊| 160493/162768 [27:52<00:18, 124.83it/s, now=None]
#
#
# t:  99%|█████████▊| 160506/162768 [27:52<00:18, 125.06it/s, now=None]
#
#
# t:  99%|█████████▊| 160519/162768 [27:52<00:18, 121.22it/s, now=None]
#
#
# t:  99%|█████████▊| 160533/162768 [27:52<00:17, 125.25it/s, now=None]
#
#
# t:  99%|█████████▊| 160547/162768 [27:52<00:17, 128.71it/s, now=None]
#
#
# t:  99%|█████████▊| 160560/162768 [27:52<00:17, 126.85it/s, now=None]
#
#
# t:  99%|█████████▊| 160575/162768 [27:52<00:16, 131.26it/s, now=None]
#
#
# t:  99%|█████████▊| 160589/162768 [27:52<00:17, 122.96it/s, now=None]
#
#
# t:  99%|█████████▊| 160603/162768 [27:52<00:17, 126.69it/s, now=None]
#
#
# t:  99%|█████████▊| 160619/162768 [27:53<00:16, 134.14it/s, now=None]
#
#
# t:  99%|█████████▊| 160633/162768 [27:53<00:16, 131.99it/s, now=None]
#
#
# t:  99%|█████████▊| 160647/162768 [27:53<00:17, 124.21it/s, now=None]
#
#
# t:  99%|█████████▊| 160660/162768 [27:53<00:17, 119.28it/s, now=None]
#
#
# t:  99%|█████████▊| 160673/162768 [27:53<00:18, 115.89it/s, now=None]
#
#
# t:  99%|█████████▊| 160685/162768 [27:53<00:18, 113.39it/s, now=None]
#
#
# t:  99%|█████████▊| 160697/162768 [27:53<00:19, 104.72it/s, now=None]
#
#
# t:  99%|█████████▊| 160708/162768 [27:53<00:20, 98.94it/s, now=None]
#
#
# t:  99%|█████████▊| 160719/162768 [27:54<00:22, 92.33it/s, now=None]
#
#
# t:  99%|█████████▊| 160729/162768 [27:54<00:23, 87.27it/s, now=None]
#
#
# t:  99%|█████████▉| 160738/162768 [27:54<00:24, 83.27it/s, now=None]
#
#
# t:  99%|█████████▉| 160747/162768 [27:54<00:25, 80.81it/s, now=None]
#
#
# t:  99%|█████████▉| 160756/162768 [27:54<00:25, 77.96it/s, now=None]
#
#
# t:  99%|█████████▉| 160765/162768 [27:54<00:24, 80.81it/s, now=None]
#
#
# t:  99%|█████████▉| 160774/162768 [27:54<00:26, 75.90it/s, now=None]
#
#
# t:  99%|█████████▉| 160783/162768 [27:54<00:25, 78.78it/s, now=None]
#
#
# t:  99%|█████████▉| 160792/162768 [27:54<00:25, 78.95it/s, now=None]
#
#
# t:  99%|█████████▉| 160800/162768 [27:55<00:25, 76.80it/s, now=None]
#
#
# t:  99%|█████████▉| 160808/162768 [27:55<00:26, 73.35it/s, now=None]
#
#
# t:  99%|█████████▉| 160817/162768 [27:55<00:25, 76.48it/s, now=None]
#
#
# t:  99%|█████████▉| 160825/162768 [27:55<00:25, 77.17it/s, now=None]
#
#
# t:  99%|█████████▉| 160834/162768 [27:55<00:24, 79.25it/s, now=None]
#
#
# t:  99%|█████████▉| 160843/162768 [27:55<00:23, 82.23it/s, now=None]
#
#
# t:  99%|█████████▉| 160853/162768 [27:55<00:22, 83.40it/s, now=None]
#
#
# t:  99%|█████████▉| 160863/162768 [27:55<00:22, 83.48it/s, now=None]
#
#
# t:  99%|█████████▉| 160873/162768 [27:55<00:21, 87.77it/s, now=None]
#
#
# t:  99%|█████████▉| 160882/162768 [27:56<00:21, 86.90it/s, now=None]
#
#
# t:  99%|█████████▉| 160891/162768 [27:56<00:21, 85.54it/s, now=None]
#
#
# t:  99%|█████████▉| 160901/162768 [27:56<00:21, 86.75it/s, now=None]
#
#
# t:  99%|█████████▉| 160910/162768 [27:56<00:21, 86.18it/s, now=None]
#
#
# t:  99%|█████████▉| 160919/162768 [27:56<00:21, 84.68it/s, now=None]
#
#
# t:  99%|█████████▉| 160928/162768 [27:56<00:21, 85.56it/s, now=None]
#
#
# t:  99%|█████████▉| 160937/162768 [27:56<00:22, 82.97it/s, now=None]
#
#
# t:  99%|█████████▉| 160946/162768 [27:56<00:22, 82.17it/s, now=None]
#
#
# t:  99%|█████████▉| 160955/162768 [27:56<00:23, 77.03it/s, now=None]
#
#
# t:  99%|█████████▉| 160964/162768 [27:57<00:22, 78.57it/s, now=None]
#
#
# t:  99%|█████████▉| 160974/162768 [27:57<00:21, 81.72it/s, now=None]
#
#
# t:  99%|█████████▉| 160983/162768 [27:57<00:22, 80.26it/s, now=None]
#
#
# t:  99%|█████████▉| 160992/162768 [27:57<00:22, 78.40it/s, now=None]
#
#
# t:  99%|█████████▉| 161000/162768 [27:57<00:24, 71.48it/s, now=None]
#
#
# t:  99%|█████████▉| 161008/162768 [27:57<00:24, 70.67it/s, now=None]
#
#
# t:  99%|█████████▉| 161016/162768 [27:57<00:24, 71.53it/s, now=None]
#
#
# t:  99%|█████████▉| 161024/162768 [27:57<00:24, 70.20it/s, now=None]
#
#
# t:  99%|█████████▉| 161034/162768 [27:58<00:23, 73.96it/s, now=None]
#
#
# t:  99%|█████████▉| 161042/162768 [27:58<00:22, 75.30it/s, now=None]
#
#
# t:  99%|█████████▉| 161051/162768 [27:58<00:22, 77.15it/s, now=None]
#
#
# t:  99%|█████████▉| 161060/162768 [27:58<00:22, 76.97it/s, now=None]
#
#
# t:  99%|█████████▉| 161068/162768 [27:58<00:22, 74.64it/s, now=None]
#
#
# t:  99%|█████████▉| 161076/162768 [27:58<00:22, 74.52it/s, now=None]
#
#
# t:  99%|█████████▉| 161084/162768 [27:58<00:22, 73.27it/s, now=None]
#
#
# t:  99%|█████████▉| 161092/162768 [27:58<00:22, 74.34it/s, now=None]
#
#
# t:  99%|█████████▉| 161101/162768 [27:58<00:21, 76.04it/s, now=None]
#
#
# t:  99%|█████████▉| 161110/162768 [27:59<00:20, 79.12it/s, now=None]
#
#
# t:  99%|█████████▉| 161119/162768 [27:59<00:20, 81.07it/s, now=None]
#
#
# t:  99%|█████████▉| 161128/162768 [27:59<00:20, 80.23it/s, now=None]
#
#
# t:  99%|█████████▉| 161137/162768 [27:59<00:21, 76.15it/s, now=None]
#
#
# t:  99%|█████████▉| 161145/162768 [27:59<00:21, 76.55it/s, now=None]
#
#
# t:  99%|█████████▉| 161153/162768 [27:59<00:22, 73.07it/s, now=None]
#
#
# t:  99%|█████████▉| 161161/162768 [27:59<00:22, 70.80it/s, now=None]
#
#
# t:  99%|█████████▉| 161169/162768 [27:59<00:23, 66.65it/s, now=None]
#
#
# t:  99%|█████████▉| 161177/162768 [27:59<00:23, 69.00it/s, now=None]
#
#
# t:  99%|█████████▉| 161184/162768 [28:00<00:22, 69.19it/s, now=None]
#
#
# t:  99%|█████████▉| 161193/162768 [28:00<00:21, 73.97it/s, now=None]
#
#
# t:  99%|█████████▉| 161202/162768 [28:00<00:20, 77.95it/s, now=None]
#
#
# t:  99%|█████████▉| 161210/162768 [28:00<00:19, 78.18it/s, now=None]
#
#
# t:  99%|█████████▉| 161218/162768 [28:00<00:19, 78.06it/s, now=None]
#
#
# t:  99%|█████████▉| 161226/162768 [28:00<00:20, 77.04it/s, now=None]
#
#
# t:  99%|█████████▉| 161234/162768 [28:00<00:20, 75.67it/s, now=None]
#
#
# t:  99%|█████████▉| 161242/162768 [28:00<00:20, 75.01it/s, now=None]
#
#
# t:  99%|█████████▉| 161250/162768 [28:00<00:19, 75.96it/s, now=None]
#
#
# t:  99%|█████████▉| 161258/162768 [28:01<00:21, 71.21it/s, now=None]
#
#
# t:  99%|█████████▉| 161267/162768 [28:01<00:20, 71.74it/s, now=None]
#
#
# t:  99%|█████████▉| 161277/162768 [28:01<00:19, 76.99it/s, now=None]
#
#
# t:  99%|█████████▉| 161287/162768 [28:01<00:18, 80.22it/s, now=None]
#
#
# t:  99%|█████████▉| 161296/162768 [28:01<00:18, 77.57it/s, now=None]
#
#
# t:  99%|█████████▉| 161304/162768 [28:01<00:19, 76.65it/s, now=None]
#
#
# t:  99%|█████████▉| 161313/162768 [28:01<00:18, 77.54it/s, now=None]
#
#
# t:  99%|█████████▉| 161321/162768 [28:01<00:19, 74.60it/s, now=None]
#
#
# t:  99%|█████████▉| 161329/162768 [28:01<00:21, 67.70it/s, now=None]
#
#
# t:  99%|█████████▉| 161339/162768 [28:02<00:19, 72.96it/s, now=None]
#
#
# t:  99%|█████████▉| 161348/162768 [28:02<00:18, 77.07it/s, now=None]
#
#
# t:  99%|█████████▉| 161356/162768 [28:02<00:18, 75.91it/s, now=None]
#
#
# t:  99%|█████████▉| 161364/162768 [28:02<00:18, 74.52it/s, now=None]
#
#
# t:  99%|█████████▉| 161373/162768 [28:02<00:17, 78.65it/s, now=None]
#
#
# t:  99%|█████████▉| 161381/162768 [28:02<00:19, 72.84it/s, now=None]
#
#
# t:  99%|█████████▉| 161389/162768 [28:02<00:19, 69.94it/s, now=None]
#
#
# t:  99%|█████████▉| 161397/162768 [28:02<00:20, 67.87it/s, now=None]
#
#
# t:  99%|█████████▉| 161404/162768 [28:02<00:19, 68.40it/s, now=None]
#
#
# t:  99%|█████████▉| 161413/162768 [28:03<00:18, 72.28it/s, now=None]
#
#
# t:  99%|█████████▉| 161423/162768 [28:03<00:17, 79.06it/s, now=None]
#
#
# t:  99%|█████████▉| 161433/162768 [28:03<00:16, 83.14it/s, now=None]
#
#
# t:  99%|█████████▉| 161443/162768 [28:03<00:15, 85.45it/s, now=None]
#
#
# t:  99%|█████████▉| 161452/162768 [28:03<00:15, 83.87it/s, now=None]
#
#
# t:  99%|█████████▉| 161461/162768 [28:03<00:15, 84.01it/s, now=None]
#
#
# t:  99%|█████████▉| 161472/162768 [28:03<00:14, 87.32it/s, now=None]
#
#
# t:  99%|█████████▉| 161481/162768 [28:03<00:15, 82.23it/s, now=None]
#
#
# t:  99%|█████████▉| 161490/162768 [28:04<00:15, 81.82it/s, now=None]
#
#
# t:  99%|█████████▉| 161499/162768 [28:04<00:15, 80.95it/s, now=None]
#
#
# t:  99%|█████████▉| 161508/162768 [28:04<00:15, 79.47it/s, now=None]
#
#
# t:  99%|█████████▉| 161516/162768 [28:04<00:15, 79.12it/s, now=None]
#
#
# t:  99%|█████████▉| 161524/162768 [28:04<00:16, 75.09it/s, now=None]
#
#
# t:  99%|█████████▉| 161533/162768 [28:04<00:16, 75.87it/s, now=None]
#
#
# t:  99%|█████████▉| 161543/162768 [28:04<00:15, 80.79it/s, now=None]
#
#
# t:  99%|█████████▉| 161552/162768 [28:04<00:14, 82.03it/s, now=None]
#
#
# t:  99%|█████████▉| 161561/162768 [28:04<00:15, 75.59it/s, now=None]
#
#
# t:  99%|█████████▉| 161571/162768 [28:05<00:14, 81.74it/s, now=None]
#
#
# t:  99%|█████████▉| 161580/162768 [28:05<00:14, 81.67it/s, now=None]
#
#
# t:  99%|█████████▉| 161591/162768 [28:05<00:13, 88.21it/s, now=None]
#
#
# t:  99%|█████████▉| 161605/162768 [28:05<00:11, 101.57it/s, now=None]
#
#
# t:  99%|█████████▉| 161616/162768 [28:05<00:11, 103.44it/s, now=None]
#
#
# t:  99%|█████████▉| 161629/162768 [28:05<00:10, 110.17it/s, now=None]
#
#
# t:  99%|█████████▉| 161642/162768 [28:05<00:09, 114.99it/s, now=None]
#
#
# t:  99%|█████████▉| 161656/162768 [28:05<00:09, 121.92it/s, now=None]
#
#
# t:  99%|█████████▉| 161669/162768 [28:05<00:08, 123.92it/s, now=None]
#
#
# t:  99%|█████████▉| 161682/162768 [28:05<00:09, 120.32it/s, now=None]
#
#
# t:  99%|█████████▉| 161696/162768 [28:06<00:08, 125.59it/s, now=None]
#
#
# t:  99%|█████████▉| 161709/162768 [28:06<00:08, 118.83it/s, now=None]
#
#
# t:  99%|█████████▉| 161721/162768 [28:06<00:09, 114.54it/s, now=None]
#
#
# t:  99%|█████████▉| 161734/162768 [28:06<00:08, 117.47it/s, now=None]
#
#
# t:  99%|█████████▉| 161748/162768 [28:06<00:08, 122.89it/s, now=None]
#
#
# t:  99%|█████████▉| 161761/162768 [28:06<00:08, 120.03it/s, now=None]
#
#
# t:  99%|█████████▉| 161774/162768 [28:06<00:08, 120.74it/s, now=None]
#
#
# t:  99%|█████████▉| 161787/162768 [28:06<00:08, 122.04it/s, now=None]
#
#
# t:  99%|█████████▉| 161800/162768 [28:06<00:08, 118.77it/s, now=None]
#
#
# t:  99%|█████████▉| 161812/162768 [28:07<00:08, 117.65it/s, now=None]
#
#
# t:  99%|█████████▉| 161824/162768 [28:07<00:08, 111.04it/s, now=None]
#
#
# t:  99%|█████████▉| 161836/162768 [28:07<00:08, 107.31it/s, now=None]
#
#
# t:  99%|█████████▉| 161849/162768 [28:07<00:08, 110.80it/s, now=None]
#
#
# t:  99%|█████████▉| 161862/162768 [28:07<00:07, 114.62it/s, now=None]
#
#
# t:  99%|█████████▉| 161874/162768 [28:07<00:08, 110.95it/s, now=None]
#
#
# t:  99%|█████████▉| 161888/162768 [28:07<00:07, 117.48it/s, now=None]
#
#
# t:  99%|█████████▉| 161900/162768 [28:07<00:07, 109.11it/s, now=None]
#
#
# t:  99%|█████████▉| 161912/162768 [28:07<00:07, 110.76it/s, now=None]
#
#
# t:  99%|█████████▉| 161924/162768 [28:08<00:07, 109.51it/s, now=None]
#
#
# t:  99%|█████████▉| 161936/162768 [28:08<00:07, 111.01it/s, now=None]
#
#
# t:  99%|█████████▉| 161948/162768 [28:08<00:07, 113.04it/s, now=None]
#
#
# t: 100%|█████████▉| 161961/162768 [28:08<00:06, 116.85it/s, now=None]
#
#
# t: 100%|█████████▉| 161975/162768 [28:08<00:06, 123.12it/s, now=None]
#
#
# t: 100%|█████████▉| 161989/162768 [28:08<00:06, 127.63it/s, now=None]
#
#
# t: 100%|█████████▉| 162002/162768 [28:08<00:06, 125.08it/s, now=None]
#
#
# t: 100%|█████████▉| 162016/162768 [28:08<00:05, 129.12it/s, now=None]
#
#
# t: 100%|█████████▉| 162031/162768 [28:08<00:05, 132.66it/s, now=None]
#
#
# t: 100%|█████████▉| 162045/162768 [28:09<00:05, 123.75it/s, now=None]
#
#
# t: 100%|█████████▉| 162059/162768 [28:09<00:05, 127.44it/s, now=None]
#
#
# t: 100%|█████████▉| 162072/162768 [28:09<00:06, 115.71it/s, now=None]
#
#
# t: 100%|█████████▉| 162087/162768 [28:09<00:05, 123.90it/s, now=None]
#
#
# t: 100%|█████████▉| 162100/162768 [28:09<00:05, 124.03it/s, now=None]
#
#
# t: 100%|█████████▉| 162113/162768 [28:09<00:05, 124.11it/s, now=None]
#
#
# t: 100%|█████████▉| 162126/162768 [28:09<00:05, 119.83it/s, now=None]
#
#
# t: 100%|█████████▉| 162139/162768 [28:09<00:05, 120.75it/s, now=None]
#
#
# t: 100%|█████████▉| 162152/162768 [28:09<00:05, 119.63it/s, now=None]
#
#
# t: 100%|█████████▉| 162165/162768 [28:10<00:05, 117.79it/s, now=None]
#
#
# t: 100%|█████████▉| 162178/162768 [28:10<00:04, 120.93it/s, now=None]
#
#
# t: 100%|█████████▉| 162191/162768 [28:10<00:04, 120.68it/s, now=None]
#
#
# t: 100%|█████████▉| 162204/162768 [28:10<00:04, 121.44it/s, now=None]
#
#
# t: 100%|█████████▉| 162217/162768 [28:10<00:04, 121.66it/s, now=None]
#
#
# t: 100%|█████████▉| 162230/162768 [28:10<00:04, 121.41it/s, now=None]
#
#
# t: 100%|█████████▉| 162243/162768 [28:10<00:04, 123.04it/s, now=None]
#
#
# t: 100%|█████████▉| 162256/162768 [28:10<00:04, 120.69it/s, now=None]
#
#
# t: 100%|█████████▉| 162269/162768 [28:10<00:04, 117.46it/s, now=None]
#
#
# t: 100%|█████████▉| 162284/162768 [28:11<00:03, 125.95it/s, now=None]
#
#
# t: 100%|█████████▉| 162297/162768 [28:11<00:03, 120.04it/s, now=None]
#
#
# t: 100%|█████████▉| 162311/162768 [28:11<00:03, 124.25it/s, now=None]
#
#
# t: 100%|█████████▉| 162325/162768 [28:11<00:03, 127.22it/s, now=None]
#
#
# t: 100%|█████████▉| 162338/162768 [28:11<00:03, 123.94it/s, now=None]
#
#
# t: 100%|█████████▉| 162352/162768 [28:11<00:03, 128.02it/s, now=None]
#
#
# t: 100%|█████████▉| 162365/162768 [28:11<00:03, 116.75it/s, now=None]
#
#
# t: 100%|█████████▉| 162379/162768 [28:11<00:03, 121.32it/s, now=None]
#
#
# t: 100%|█████████▉| 162394/162768 [28:11<00:02, 126.22it/s, now=None]
#
#
# t: 100%|█████████▉| 162409/162768 [28:12<00:02, 130.88it/s, now=None]
#
#
# t: 100%|█████████▉| 162423/162768 [28:12<00:02, 129.60it/s, now=None]
#
#
# t: 100%|█████████▉| 162438/162768 [28:12<00:02, 134.09it/s, now=None]
#
#
# t: 100%|█████████▉| 162452/162768 [28:12<00:02, 128.44it/s, now=None]
#
#
# t: 100%|█████████▉| 162465/162768 [28:12<00:02, 127.00it/s, now=None]
#
#
# t: 100%|█████████▉| 162478/162768 [28:12<00:02, 126.49it/s, now=None]
#
#
# t: 100%|█████████▉| 162491/162768 [28:12<00:02, 124.58it/s, now=None]
#
#
# t: 100%|█████████▉| 162506/162768 [28:12<00:02, 129.20it/s, now=None]
#
#
# t: 100%|█████████▉| 162519/162768 [28:12<00:01, 127.36it/s, now=None]
#
#
# t: 100%|█████████▉| 162532/162768 [28:12<00:01, 127.32it/s, now=None]
#
#
# t: 100%|█████████▉| 162545/162768 [28:13<00:01, 126.63it/s, now=None]
#
#
# t: 100%|█████████▉| 162558/162768 [28:13<00:01, 124.57it/s, now=None]
#
#
# t: 100%|█████████▉| 162571/162768 [28:13<00:01, 121.37it/s, now=None]
#
#
# t: 100%|█████████▉| 162586/162768 [28:13<00:01, 127.77it/s, now=None]
#
#
# t: 100%|█████████▉| 162599/162768 [28:13<00:01, 124.37it/s, now=None]
#
#
# t: 100%|█████████▉| 162612/162768 [28:13<00:01, 125.88it/s, now=None]
#
#
# t: 100%|█████████▉| 162629/162768 [28:13<00:01, 138.14it/s, now=None]
#
#
# t: 100%|█████████▉| 162643/162768 [28:13<00:00, 133.27it/s, now=None]
#
#
# t: 100%|█████████▉| 162657/162768 [28:13<00:00, 128.40it/s, now=None]
#
#
# t: 100%|█████████▉| 162671/162768 [28:14<00:00, 130.04it/s, now=None]
#
#
# t: 100%|█████████▉| 162685/162768 [28:14<00:00, 121.03it/s, now=None]
#
#
# t: 100%|█████████▉| 162701/162768 [28:14<00:00, 131.08it/s, now=None]
#
#
# t: 100%|█████████▉| 162715/162768 [28:14<00:00, 124.05it/s, now=None]
#
#
# t: 100%|█████████▉| 162728/162768 [28:14<00:00, 123.25it/s, now=None]
#
#
# t: 100%|█████████▉| 162742/162768 [28:14<00:00, 125.97it/s, now=None]
#
#
# t: 100%|█████████▉| 162756/162768 [28:14<00:00, 127.41it/s, now=None]
#
#
#
#
#
# t:  26%|██▌       | 41704/162768 [1:36:49<11:43, 171.98it/s, now=None]
#
# t:  68%|██████▊   | 110460/162768 [1:28:48<11:16, 77.28it/s, now=None]
#
#
#
# t:  26%|██▌       | 41704/162768 [1:36:49<11:43, 171.98it/s, now=None]
#
# t:  68%|██████▊   | 110460/162768 [1:28:48<11:16, 77.28it/s, now=None]
# t:   1%|          | 1362/162768 [1:30:22<16:44, 160.65it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/Jose_Data_Videos_CSV/Subject_12_M/Subject_12_M_Right.mp4
